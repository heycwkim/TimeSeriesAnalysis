# %% [markdown]
# # Library

# %%
# !pip install arch
# !pip install tqdm

# %%
import os
import numpy as np
import pandas as pd
pd.options.display.float_format = '{:,.2f}'.format
pd.options.display.max_rows = 1000
pd.options.display.max_columns = 1000
import itertools
from tqdm import tqdm

from scipy import stats
import statsmodels.api as sm
import arch

# %% [markdown]
# # Logic Generator for Extracting of Data
# **[스키마: 구단위 레벨로 지수 존재]**
# 전국 수도권(서울/경기/인천) 6대광역시(부산/대구/광주/대전/울산/인천) 5대광역시(부산/대구/광주/대전/울산) 기타지방(나머지)
# 서울 강남 강북 경기 인천 부산 대구 광주 대전 울산
# 강원 충북 충남 전북 전남 경북 경남 제주
#
# **[선별: 구단위 제외한 지수 중 전국지역]**
# 서울 강북 강남 6대광역시 경기 강원 충북 충남 전북 전남 경북 경남 (제주) 기타지방(수도권광역시제외지역)
#
# **[선별: 구단위 제외한 값으로 아파트/단독/연립 모두 존재 지역]**
# 서울 강북 강남 6개광역시 경기 기타지방(수도권광역시제외지역)
# (강원 충북 충남 전북 전남 경북 경남은 아파트만 값 존재)

# %%
# Calculate Logic of Data Extraction from KB Housing File
def Extracting_IndexValue(type_names, region_names, sheet_names, selected_names, sheet_val, col_val):
    col_names = ['Time']
    for combination in itertools.product(region_names, type_names):
        col_names.append(combination[0]+':'+combination[1])

    col_logic = ['='+sheet_names[0]+'!A5']
    for combination in itertools.product(selected_names, sheet_names):
        col_logic.append('='+combination[1]+'!'+combination[0])
    index_val = pd.DataFrame(col_logic, index=col_names).T

    val_index = []
    for combination in itertools.product(sheet_val, col_val):
        val_index.append('='+combination[0]+'!'+combination[1])
    value = pd.DataFrame(val_index, index=col_names[1:]).T
    return index_val, value

type_names = ['Apartments(HPI)', 'Detached_Houses(HPI)', 'Row_Houses(HPI)']
region_names = ['Seoul', 'Northern Seoul', 'Southern Seoul', '6 Large Cities', 'Gyeonggi-do', 'Gangwon-do', 'Chungcheongbuk-do', 'Chungcheongnam-do', 
                'Jeollabuk-do', 'Jeollanam-do', 'Gyeongsangbuk-do', 'Gyeongsangnam-do', 'Non-Metropolitan Area']
sheet_names = ['매매APT', '매매단독', '매매연립']
selected_names = ['C5', 'D5', 'S5', 'AE5', 'CJ5', 'EE5', 'EI5', 'EQ5', 'FA5', 'FG5', 'FL5', 'FS5', 'GG5']
sheet_val = ['평균매매']
col_val = ['I125', 'J125', 'K125', 'M125', 'N125', 'O125', 'Q125', 'R125', 'S125', 'U125', 'V125', 'W125', 'AU125', 'AV125', 'AW125', 
               'AY125', '_125', '_125', 'BA125', '_125', '_125', 'BC125', '_125', '_125', 'BE125', '_125', '_125', 'BG125', '_125', '_125', 
               'BI125', '_125', '_125', 'BK125', '_125', '_125', 'BM125', 'BN125', 'BO125']
HPI_index, HPI_value = Extracting_IndexValue(type_names, region_names, sheet_names, selected_names, sheet_val, col_val)

type_names = ['Apartments(JDI)', 'Detached_Houses(JDI)', 'Row_Houses(JDI)']
region_names = ['Seoul', 'Northern Seoul', 'Southern Seoul', '6 Large Cities', 'Gyeonggi-do', 'Gangwon-do', 'Chungcheongbuk-do', 'Chungcheongnam-do', 
                'Jeollabuk-do', 'Jeollanam-do', 'Gyeongsangbuk-do', 'Gyeongsangnam-do', 'Non-Metropolitan Area']
sheet_names = ['전세APT', '전세단독', '전세연립']
selected_names = ['C5', 'D5', 'S5', 'AE5', 'CJ5', 'EE5', 'EI5', 'EQ5', 'FA5', 'FG5', 'FL5', 'FS5', 'GG5']
sheet_val = ['평균전세']
col_val = ['I95', 'J95', 'K95', 'M95', 'N95', 'O95', 'Q95', 'R95', 'S95', 'U95', 'V95', 'W95', 'AU95', 'AV95', 'AW95', 
               'AY95', '_95', '_95', 'BA95', '_95', '_95', 'BC95', '_95', '_95', 'BE95', '_95', '_95', 'BG95', '_95', '_95', 
               'BI95', '_95', '_95', 'BK95', '_95', '_95', 'BM95', 'BN95', 'BO95']
JDI_index, JDI_value = Extracting_IndexValue(type_names, region_names, sheet_names, selected_names, sheet_val, col_val)
display(HPI_index)
display(HPI_value)
display(JDI_index)
display(JDI_value)
# Out:
#         Time Seoul:Apartments(HPI) Seoul:Detached_Houses(HPI)  \
# 0  =매매APT!A5             =매매APT!C5                   =매매단독!C5
#
#   Seoul:Row_Houses(HPI) Northern Seoul:Apartments(HPI)  \
# 0              =매매연립!C5                      =매매APT!D5
#
#   Northern Seoul:Detached_Houses(HPI) Northern Seoul:Row_Houses(HPI)  \
# 0                            =매매단독!D5                       =매매연립!D5
#
#   Southern Seoul:Apartments(HPI) Southern Seoul:Detached_Houses(HPI)  \
# 0                      =매매APT!S5                            =매매단독!S5
#
#   Southern Seoul:Row_Houses(HPI) 6 Large Cities:Apartments(HPI)  \
# 0                       =매매연립!S5                     =매매APT!AE5
#
#   6 Large Cities:Detached_Houses(HPI) 6 Large Cities:Row_Houses(HPI)  \
# 0                           =매매단독!AE5                      =매매연립!AE5
#
#   Gyeonggi-do:Apartments(HPI) Gyeonggi-do:Detached_Houses(HPI)  \
# 0                  =매매APT!CJ5                        =매매단독!CJ5
#
#   Gyeonggi-do:Row_Houses(HPI) Gangwon-do:Apartments(HPI)  \
# 0                   =매매연립!CJ5                 =매매APT!EE5
#
#   Gangwon-do:Detached_Houses(HPI) Gangwon-do:Row_Houses(HPI)  \
# 0                       =매매단독!EE5                  =매매연립!EE5
#
#   Chungcheongbuk-do:Apartments(HPI) Chungcheongbuk-do:Detached_Houses(HPI)  \
# 0                        =매매APT!EI5                              =매매단독!EI5
#
#   Chungcheongbuk-do:Row_Houses(HPI) Chungcheongnam-do:Apartments(HPI)  \
# 0                         =매매연립!EI5                        =매매APT!EQ5
#
#   Chungcheongnam-do:Detached_Houses(HPI) Chungcheongnam-do:Row_Houses(HPI)  \
# 0                              =매매단독!EQ5                         =매매연립!EQ5
#
#   Jeollabuk-do:Apartments(HPI) Jeollabuk-do:Detached_Houses(HPI)  \
# 0                   =매매APT!FA5                         =매매단독!FA5
#
#   Jeollabuk-do:Row_Houses(HPI) Jeollanam-do:Apartments(HPI)  \
# 0                    =매매연립!FA5                   =매매APT!FG5
#
#   Jeollanam-do:Detached_Houses(HPI) Jeollanam-do:Row_Houses(HPI)  \
# 0                         =매매단독!FG5                    =매매연립!FG5
#
#   Gyeongsangbuk-do:Apartments(HPI) Gyeongsangbuk-do:Detached_Houses(HPI)  \
# 0                       =매매APT!FL5                             =매매단독!FL5
#
#   Gyeongsangbuk-do:Row_Houses(HPI) Gyeongsangnam-do:Apartments(HPI)  \
# 0                        =매매연립!FL5                       =매매APT!FS5
#
#   Gyeongsangnam-do:Detached_Houses(HPI) Gyeongsangnam-do:Row_Houses(HPI)  \
# 0                             =매매단독!FS5                        =매매연립!FS5
#
#   Non-Metropolitan Area:Apartments(HPI)  \
# 0                            =매매APT!GG5
#
#   Non-Metropolitan Area:Detached_Houses(HPI)  \
# 0                                  =매매단독!GG5
#
#   Non-Metropolitan Area:Row_Houses(HPI)
# 0                             =매매연립!GG5
#   Seoul:Apartments(HPI) Seoul:Detached_Houses(HPI) Seoul:Row_Houses(HPI)  \
# 0            =평균매매!I125                 =평균매매!J125            =평균매매!K125
#
#   Northern Seoul:Apartments(HPI) Northern Seoul:Detached_Houses(HPI)  \
# 0                     =평균매매!M125                          =평균매매!N125
#
#   Northern Seoul:Row_Houses(HPI) Southern Seoul:Apartments(HPI)  \
# 0                     =평균매매!O125                     =평균매매!Q125
#
#   Southern Seoul:Detached_Houses(HPI) Southern Seoul:Row_Houses(HPI)  \
# 0                          =평균매매!R125                     =평균매매!S125
#
#   6 Large Cities:Apartments(HPI) 6 Large Cities:Detached_Houses(HPI)  \
# 0                     =평균매매!U125                          =평균매매!V125
#
#   6 Large Cities:Row_Houses(HPI) Gyeonggi-do:Apartments(HPI)  \
# 0                     =평균매매!W125                 =평균매매!AU125
#
#   Gyeonggi-do:Detached_Houses(HPI) Gyeonggi-do:Row_Houses(HPI)  \
# 0                      =평균매매!AV125                 =평균매매!AW125
#
#   Gangwon-do:Apartments(HPI) Gangwon-do:Detached_Houses(HPI)  \
# 0                =평균매매!AY125                      =평균매매!_125
#
#   Gangwon-do:Row_Houses(HPI) Chungcheongbuk-do:Apartments(HPI)  \
# 0                 =평균매매!_125                       =평균매매!BA125
#
#   Chungcheongbuk-do:Detached_Houses(HPI) Chungcheongbuk-do:Row_Houses(HPI)  \
# 0                             =평균매매!_125                        =평균매매!_125
#
#   Chungcheongnam-do:Apartments(HPI) Chungcheongnam-do:Detached_Houses(HPI)  \
# 0                       =평균매매!BC125                             =평균매매!_125
#
#   Chungcheongnam-do:Row_Houses(HPI) Jeollabuk-do:Apartments(HPI)  \
# 0                        =평균매매!_125                  =평균매매!BE125
#
#   Jeollabuk-do:Detached_Houses(HPI) Jeollabuk-do:Row_Houses(HPI)  \
# 0                        =평균매매!_125                   =평균매매!_125
#
#   Jeollanam-do:Apartments(HPI) Jeollanam-do:Detached_Houses(HPI)  \
# 0                  =평균매매!BG125                        =평균매매!_125
#
#   Jeollanam-do:Row_Houses(HPI) Gyeongsangbuk-do:Apartments(HPI)  \
# 0                   =평균매매!_125                      =평균매매!BI125
#
#   Gyeongsangbuk-do:Detached_Houses(HPI) Gyeongsangbuk-do:Row_Houses(HPI)  \
# 0                            =평균매매!_125                       =평균매매!_125
#
#   Gyeongsangnam-do:Apartments(HPI) Gyeongsangnam-do:Detached_Houses(HPI)  \
# 0                      =평균매매!BK125                            =평균매매!_125
#
#   Gyeongsangnam-do:Row_Houses(HPI) Non-Metropolitan Area:Apartments(HPI)  \
# 0                       =평균매매!_125                           =평균매매!BM125
#
#   Non-Metropolitan Area:Detached_Houses(HPI)  \
# 0                                =평균매매!BN125
#
#   Non-Metropolitan Area:Row_Houses(HPI)
# 0                           =평균매매!BO125
#         Time Seoul:Apartments(JDI) Seoul:Detached_Houses(JDI)  \
# 0  =전세APT!A5             =전세APT!C5                   =전세단독!C5
#
#   Seoul:Row_Houses(JDI) Northern Seoul:Apartments(JDI)  \
# 0              =전세연립!C5                      =전세APT!D5
#
#   Northern Seoul:Detached_Houses(JDI) Northern Seoul:Row_Houses(JDI)  \
# 0                            =전세단독!D5                       =전세연립!D5
#
#   Southern Seoul:Apartments(JDI) Southern Seoul:Detached_Houses(JDI)  \
# 0                      =전세APT!S5                            =전세단독!S5
#
#   Southern Seoul:Row_Houses(JDI) 6 Large Cities:Apartments(JDI)  \
# 0                       =전세연립!S5                     =전세APT!AE5
#
#   6 Large Cities:Detached_Houses(JDI) 6 Large Cities:Row_Houses(JDI)  \
# 0                           =전세단독!AE5                      =전세연립!AE5
#
#   Gyeonggi-do:Apartments(JDI) Gyeonggi-do:Detached_Houses(JDI)  \
# 0                  =전세APT!CJ5                        =전세단독!CJ5
#
#   Gyeonggi-do:Row_Houses(JDI) Gangwon-do:Apartments(JDI)  \
# 0                   =전세연립!CJ5                 =전세APT!EE5
#
#   Gangwon-do:Detached_Houses(JDI) Gangwon-do:Row_Houses(JDI)  \
# 0                       =전세단독!EE5                  =전세연립!EE5
#
#   Chungcheongbuk-do:Apartments(JDI) Chungcheongbuk-do:Detached_Houses(JDI)  \
# 0                        =전세APT!EI5                              =전세단독!EI5
#
#   Chungcheongbuk-do:Row_Houses(JDI) Chungcheongnam-do:Apartments(JDI)  \
# 0                         =전세연립!EI5                        =전세APT!EQ5
#
#   Chungcheongnam-do:Detached_Houses(JDI) Chungcheongnam-do:Row_Houses(JDI)  \
# 0                              =전세단독!EQ5                         =전세연립!EQ5
#
#   Jeollabuk-do:Apartments(JDI) Jeollabuk-do:Detached_Houses(JDI)  \
# 0                   =전세APT!FA5                         =전세단독!FA5
#
#   Jeollabuk-do:Row_Houses(JDI) Jeollanam-do:Apartments(JDI)  \
# 0                    =전세연립!FA5                   =전세APT!FG5
#
#   Jeollanam-do:Detached_Houses(JDI) Jeollanam-do:Row_Houses(JDI)  \
# 0                         =전세단독!FG5                    =전세연립!FG5
#
#   Gyeongsangbuk-do:Apartments(JDI) Gyeongsangbuk-do:Detached_Houses(JDI)  \
# 0                       =전세APT!FL5                             =전세단독!FL5
#
#   Gyeongsangbuk-do:Row_Houses(JDI) Gyeongsangnam-do:Apartments(JDI)  \
# 0                        =전세연립!FL5                       =전세APT!FS5
#
#   Gyeongsangnam-do:Detached_Houses(JDI) Gyeongsangnam-do:Row_Houses(JDI)  \
# 0                             =전세단독!FS5                        =전세연립!FS5
#
#   Non-Metropolitan Area:Apartments(JDI)  \
# 0                            =전세APT!GG5
#
#   Non-Metropolitan Area:Detached_Houses(JDI)  \
# 0                                  =전세단독!GG5
#
#   Non-Metropolitan Area:Row_Houses(JDI)
# 0                             =전세연립!GG5
#   Seoul:Apartments(JDI) Seoul:Detached_Houses(JDI) Seoul:Row_Houses(JDI)  \
# 0             =평균전세!I95                  =평균전세!J95             =평균전세!K95
#
#   Northern Seoul:Apartments(JDI) Northern Seoul:Detached_Houses(JDI)  \
# 0                      =평균전세!M95                           =평균전세!N95
#
#   Northern Seoul:Row_Houses(JDI) Southern Seoul:Apartments(JDI)  \
# 0                      =평균전세!O95                      =평균전세!Q95
#
#   Southern Seoul:Detached_Houses(JDI) Southern Seoul:Row_Houses(JDI)  \
# 0                           =평균전세!R95                      =평균전세!S95
#
#   6 Large Cities:Apartments(JDI) 6 Large Cities:Detached_Houses(JDI)  \
# 0                      =평균전세!U95                           =평균전세!V95
#
#   6 Large Cities:Row_Houses(JDI) Gyeonggi-do:Apartments(JDI)  \
# 0                      =평균전세!W95                  =평균전세!AU95
#
#   Gyeonggi-do:Detached_Houses(JDI) Gyeonggi-do:Row_Houses(JDI)  \
# 0                       =평균전세!AV95                  =평균전세!AW95
#
#   Gangwon-do:Apartments(JDI) Gangwon-do:Detached_Houses(JDI)  \
# 0                 =평균전세!AY95                       =평균전세!_95
#
#   Gangwon-do:Row_Houses(JDI) Chungcheongbuk-do:Apartments(JDI)  \
# 0                  =평균전세!_95                        =평균전세!BA95
#
#   Chungcheongbuk-do:Detached_Houses(JDI) Chungcheongbuk-do:Row_Houses(JDI)  \
# 0                              =평균전세!_95                         =평균전세!_95
#
#   Chungcheongnam-do:Apartments(JDI) Chungcheongnam-do:Detached_Houses(JDI)  \
# 0                        =평균전세!BC95                              =평균전세!_95
#
#   Chungcheongnam-do:Row_Houses(JDI) Jeollabuk-do:Apartments(JDI)  \
# 0                         =평균전세!_95                   =평균전세!BE95
#
#   Jeollabuk-do:Detached_Houses(JDI) Jeollabuk-do:Row_Houses(JDI)  \
# 0                         =평균전세!_95                    =평균전세!_95
#
#   Jeollanam-do:Apartments(JDI) Jeollanam-do:Detached_Houses(JDI)  \
# 0                   =평균전세!BG95                         =평균전세!_95
#
#   Jeollanam-do:Row_Houses(JDI) Gyeongsangbuk-do:Apartments(JDI)  \
# 0                    =평균전세!_95                       =평균전세!BI95
#
#   Gyeongsangbuk-do:Detached_Houses(JDI) Gyeongsangbuk-do:Row_Houses(JDI)  \
# 0                             =평균전세!_95                        =평균전세!_95
#
#   Gyeongsangnam-do:Apartments(JDI) Gyeongsangnam-do:Detached_Houses(JDI)  \
# 0                       =평균전세!BK95                             =평균전세!_95
#
#   Gyeongsangnam-do:Row_Houses(JDI) Non-Metropolitan Area:Apartments(JDI)  \
# 0                        =평균전세!_95                            =평균전세!BM95
#
#   Non-Metropolitan Area:Detached_Houses(JDI)  \
# 0                                 =평균전세!BN95
#
#   Non-Metropolitan Area:Row_Houses(JDI)
# 0                            =평균전세!BO95

# %% [markdown]
# # Summary of Function

# %%
# Summary Statistics
def summary_statistics(Target, lag_candi1 = 10, lag_candi2 = 20):
    ks_stat_all, ks_pvalue_all, jb_stat_all, jb_pvalue_all = [], [], [], []
    arch_stat_all_lag1, arch_pvalue_all_lag1, arch_stat_all_lag2, arch_pvalue_all_lag2 = [], [], [], []
    lb_stat_all_lag1, lb_pvalue_all_lag1, lb_stat_all_lag2, lb_pvalue_all_lag2 = [], [], [], []
    lb_stat_all_lag12, lb_pvalue_all_lag12, lb_stat_all_lag22, lb_pvalue_all_lag22 = [], [], [], []
    adf_stat_all, adf_pvalue_all = [], []
    for col in Target.columns:
        # Kolmogorov–Smirnov Test
        ks_stat, ks_pvalue = stats.kstest(Target[col], cdf='norm', alternative='two-sided', mode='asymp')
        ks_stat_all.append(ks_stat)
        ks_pvalue_all.append(ks_pvalue)
        # Jarque–Bera Test
        jb_stat, jb_pvalue = stats.jarque_bera(Target[col])
        jb_stat_all.append(jb_stat)
        jb_pvalue_all.append(jb_pvalue)
        # ARCH Test
        arch_stat, arch_pvalue, arch_fstat, arch_fpvalue = sm.stats.diagnostic.het_arch(Target[col], maxlag=lag_candi1)
        arch_stat_all_lag1.append(arch_stat)
        arch_pvalue_all_lag1.append(arch_pvalue)
        arch_stat, arch_pvalue, arch_fstat, arch_fpvalue = sm.stats.diagnostic.het_arch(Target[col], maxlag=lag_candi2)
        arch_stat_all_lag2.append(arch_stat)
        arch_pvalue_all_lag2.append(arch_pvalue)
        # Ljung-Box Test
        lb_stat, lb_pvalue = sm.stats.diagnostic.acorr_ljungbox(Target[col], lags=lag_candi1)
        lb_stat, lb_pvalue = lb_stat[lag_candi1-1], lb_pvalue[lag_candi1-1]
        lb_stat_all_lag1.append(lb_stat)
        lb_pvalue_all_lag1.append(lb_pvalue)
        lb_stat, lb_pvalue = sm.stats.diagnostic.acorr_ljungbox(Target[col], lags=lag_candi2)
        lb_stat, lb_pvalue = lb_stat[lag_candi2-1], lb_pvalue[lag_candi2-1]
        lb_stat_all_lag2.append(lb_stat)
        lb_pvalue_all_lag2.append(lb_pvalue)
        # Ljung-Box^2 Test
        lb_stat, lb_pvalue = sm.stats.diagnostic.acorr_ljungbox(Target[col]**2, lags=lag_candi1)
        lb_stat, lb_pvalue = lb_stat[lag_candi1-1], lb_pvalue[lag_candi1-1]
        lb_stat_all_lag12.append(lb_stat)
        lb_pvalue_all_lag12.append(lb_pvalue)
        lb_stat, lb_pvalue = sm.stats.diagnostic.acorr_ljungbox(Target[col]**2, lags=lag_candi2)
        lb_stat, lb_pvalue = lb_stat[lag_candi2-1], lb_pvalue[lag_candi2-1]
        lb_stat_all_lag22.append(lb_stat)
        lb_pvalue_all_lag22.append(lb_pvalue)
        # Augmented Dickey-Fuller Test
        adf_stat, adf_pvalue = sm.tsa.stattools.adfuller(Target[col], autolag='AIC')[0], sm.tsa.stattools.adfuller(Target[col], autolag='AIC')[1]
        adf_stat_all.append(adf_stat)
        adf_pvalue_all.append(adf_pvalue)
    result = pd.concat([pd.DataFrame([Target.mean(), Target.std(), Target.skew(), Target.kurt()]),
                        pd.DataFrame(ks_stat_all, index=Target.columns).T, pd.DataFrame(ks_pvalue_all, index=Target.columns).T,
                        pd.DataFrame(jb_stat_all, index=Target.columns).T, pd.DataFrame(jb_pvalue_all, index=Target.columns).T,
                        pd.DataFrame(arch_stat_all_lag1, index=Target.columns).T, pd.DataFrame(arch_pvalue_all_lag1, index=Target.columns).T,
                        pd.DataFrame(arch_stat_all_lag2, index=Target.columns).T, pd.DataFrame(arch_pvalue_all_lag2, index=Target.columns).T,
                        pd.DataFrame(lb_stat_all_lag1, index=Target.columns).T, pd.DataFrame(lb_pvalue_all_lag1, index=Target.columns).T,
                        pd.DataFrame(lb_stat_all_lag2, index=Target.columns).T, pd.DataFrame(lb_pvalue_all_lag2, index=Target.columns).T,
                        pd.DataFrame(lb_stat_all_lag12, index=Target.columns).T, pd.DataFrame(lb_pvalue_all_lag12, index=Target.columns).T,
                        pd.DataFrame(lb_stat_all_lag22, index=Target.columns).T, pd.DataFrame(lb_pvalue_all_lag22, index=Target.columns).T,
                        pd.DataFrame(adf_stat_all, index=Target.columns).T, pd.DataFrame(adf_pvalue_all, index=Target.columns).T])
    result.index = ['Mean', 'Stdev', 'Skewness', 'Kurtosis', 'Kolmogorov–Smirnov', '(p-value)', 'Jarque–Bera', '(p-value)',
                    'ARCH(10)', '(p-value)', 'ARCH(20)', '(p-value)', 'Ljung–Box(10)', '(p-value)', 'Ljung–Box(20)', '(p-value)',
                    'Ljung–Box(10)^2', '(p-value)', 'Ljung–Box(20)^2', '(p-value)', 'Augmented Dickey–Fuller', '(p-value)']
    return result

# Summary Statistics (by Type)
def Summary_AllGroup(raw_HPI, raw_JDI, Apartments_Scol, Detached_Houses_Scol, Row_Houses_Scol, Apartments_Kcol, Detached_Houses_Kcol, Row_Houses_Kcol):
    print('Summary Statistics')
    result_final = pd.DataFrame()
    result1 = summary_statistics(raw_HPI[Apartments_Scol])
    result_final = pd.concat([result_final, pd.DataFrame((result1.iloc[:4,:].T).mean(), columns=[raw_HPI[Apartments_Scol].columns[0].split(':')[1]])], axis=1)
    result2 = summary_statistics(raw_JDI[Apartments_Kcol])
    result_final = pd.concat([result_final, pd.DataFrame((result2.iloc[:4,:].T).mean(), columns=[raw_JDI[Apartments_Kcol].columns[0].split(':')[1]])], axis=1)
    result3 = summary_statistics(raw_HPI[Detached_Houses_Scol])
    result_final = pd.concat([result_final, pd.DataFrame((result3.iloc[:4,:].T).mean(), columns=[raw_HPI[Detached_Houses_Scol].columns[0].split(':')[1]])], axis=1)
    result4 = summary_statistics(raw_JDI[Detached_Houses_Kcol])
    result_final = pd.concat([result_final, pd.DataFrame((result4.iloc[:4,:].T).mean(), columns=[raw_JDI[Detached_Houses_Kcol].columns[0].split(':')[1]])], axis=1)
    result5 = summary_statistics(raw_HPI[Row_Houses_Scol])
    result_final = pd.concat([result_final, pd.DataFrame((result5.iloc[:4,:].T).mean(), columns=[raw_HPI[Row_Houses_Scol].columns[0].split(':')[1]])], axis=1)
    result6 = summary_statistics(raw_JDI[Row_Houses_Kcol])
    result_final = pd.concat([result_final, pd.DataFrame((result6.iloc[:4,:].T).mean(), columns=[raw_JDI[Row_Houses_Kcol].columns[0].split(':')[1]])], axis=1)
    display(result_final, result1.iloc[:4,:].T, result2.iloc[:4,:].T, result3.iloc[:4,:].T, result4.iloc[:4,:].T, result5.iloc[:4,:].T, result6.iloc[:4,:].T)
   
# Index to Return
def index_to_return(Target):
    log_return_df = []
    for col in Target.columns:
        log_return = []
        log_return = (np.log(Target[col]) - np.log(Target[col].shift(1)))
        log_return[0] = log_return.mean()
        log_return_df.append(log_return)
    log_return_final = pd.DataFrame(log_return_df).T
    return log_return_final

# Calulate Conditional Volatility
def conditional_volatility(Target):
    conditional_vol = []
    for col in Target.columns:
        Target_arima = sm.tsa.ARIMA(Target[col]*100, order=(1,0,1)).fit()
        Target_garch = arch.arch_model(Target_arima.resid.values, vol='Garch', p=1, o=0, q=1, dist='generalized error').fit(disp='off')
        conditional_vol.append(Target_garch.conditional_volatility)  
    conditional_vol_final = pd.DataFrame(conditional_vol, index=Target.columns, columns=Target.index).T
    return conditional_vol_final

# Rearrange of Stochastic Parameters
def get_stochastic_parameters(Target_index, Target_return, Target_cvol, deltat=1):
    parameters_final = dict()
    for col in Target_index.columns:
        parameters = pd.concat([Target_index[col], Target_return[col], Target_return[col].rolling(window=3, center=False).mean().fillna(0),
                                Target_cvol[col]/100], axis=1)
        parameters.columns = ['Index', 'Return', 'Mu', 'CVol']
        parameters['Nu'] = parameters['Mu'] - (0.5)*(parameters['CVol']**2)
        parameters['Up_return'] = np.exp(parameters['Nu']*deltat + parameters['CVol']*deltat)
        parameters['Down_return'] = np.exp(parameters['Nu']*deltat - parameters['CVol']*deltat)
        parameters_final[col] = parameters
    return parameters_final

# Grouping of Columns
def Grouping(S_real_full):
    Apartments_Scol, Apartments_Kcol, Detached_Houses_Scol, Detached_Houses_Kcol, Row_Houses_Scol, Row_Houses_Kcol = [], [], [], [], [], [] 
    for col in S_real_full.keys():
        if 'Apartments(HPI)' in col.split(':'):
            Apartments_Scol.append(col)
            Apartments_Kcol.append(col.replace('(HPI)', '(JDI)'))
        elif 'Detached_Houses(HPI)' in col.split(':'):
            Detached_Houses_Scol.append(col)
            Detached_Houses_Kcol.append(col.replace('(HPI)', '(JDI)'))
        elif 'Row_Houses(HPI)' in col.split(':'):
            Row_Houses_Scol.append(col)
            Row_Houses_Kcol.append(col.replace('(HPI)', '(JDI)'))
    return Apartments_Scol, Apartments_Kcol, Detached_Houses_Scol, Detached_Houses_Kcol, Row_Houses_Scol, Row_Houses_Kcol

# Calculate S
def S_generator(S_real, t, T):
    S = np.full((2**(T-t), T-t+1), np.nan)
    S[0][0] = S_real['Index'].iloc[t]
    for i in range(1,T-t+1): # 1~12 (2~13)
        for j in range(0,2**(i)): # 0~2^1-1/2^12-1 (1~2^1/2^12)
            if j%2 == 0:
                S[j][i] = S[int(j/2)][i-1] * S_real['Up_return'][t+(i-1)]
            else:
                S[j][i] = S[int(j/2)][i-1] * S_real['Down_return'][t+(i-1)]
    return S

# Calculate V
def V_generator(S_real, S, K_real, R_real, t, T, early_exercise):
    ### Generate V
    V_call = np.full((S.shape[0], S.shape[1]), np.nan)
    V_put = np.full((S.shape[0], S.shape[1]), np.nan)
    initial_spread = S_real['Index'][t] - K_real[t];
    V_call_early = np.full((S.shape[0], S.shape[1]-1), np.nan)
    V_put_early = np.full((S.shape[0], S.shape[1]-1), np.nan)
    Time_call_early = 0
    Time_put_early = 0
    print(T)
    for i in range(S.shape[0]-1, -1, -1): #4095~0 (4096~1)
        V_call[i][S.shape[1]-1] = S[i][S.shape[1]-1] - K_real[T] - initial_spread
        V_put[i][S.shape[1]-1] = S[i][S.shape[1]-1] - K_real[T] - initial_spread
    print(S[i][S.shape[1]-1])
    print(K_real[T])
    for j in range(0, S.shape[1]-1): #0~11 (1~12)
        for i in range(0, 2**(S.shape[1]-1-(j+1))): # 0~2^11-1/2^0(1~2^11/2^1)
            V_call[i][S.shape[1]-1-(j+1)] = (0.5 * V_call[2*i][S.shape[1]-1-j] + 0.5 * V_call[2*i+1][S.shape[1]-1-j]) / np.exp(R_real.iloc[T-j,0])
            V_put[i][S.shape[1]-1-(j+1)] = (0.5 * V_put[2*i][S.shape[1]-1-j] + 0.5 * V_put[2*i+1][S.shape[1]-1-j]) / np.exp(R_real.iloc[T-j,0])
            ### Calculate V(when early exercise is True)
            if early_exercise:
                V_call_early[i][S.shape[1]-1-(j+1)] = S[i][S.shape[1]-1-(j+1)] - K_real[T-(j+1)] - initial_spread
                if V_call_early[i][S.shape[1]-1-(j+1)] < V_call[i][S.shape[1]-1-(j+1)]:
                    V_call[i][S.shape[1]-1-(j+1)] = V_call_early[i][S.shape[1]-1-(j+1)]
                    Time_call_early = j+1
                V_put_early[i][S.shape[1]-1-(j+1)] = S[i][S.shape[1]-1-(j+1)] - K_real[T-(j+1)] - initial_spread
                if V_put_early[i][S.shape[1]-1-(j+1)] > V_put[i][S.shape[1]-1-(j+1)]:
                    V_put[i][S.shape[1]-1-(j+1)] = V_put_early[i][S.shape[1]-1-(j+1)]
                    Time_put_early = j+1
    return V_call, V_put, Time_call_early, Time_put_early

# Calculate V
def V_generator_simple(S_real, S, K_real, R_real, t, T, early_exercise):
    ### Generate V
    V_call = np.full((S.shape[0], S.shape[1]), np.nan)
    V_put = np.full((S.shape[0], S.shape[1]), np.nan)
    initial_spread = S_real['Index'][t] - K_real[t];
    V_early = np.full((S.shape[0], S.shape[1]-1), np.nan)
    Time_call_early = 0
    Time_put_early = 0
    for i in range(S.shape[0]-1, -1, -1): #4095~0 (4096~1)
        V_call[i][S.shape[1]-1] = S[i][S.shape[1]-1] - K_real[T] - initial_spread
        V_put[i][S.shape[1]-1] = S[i][S.shape[1]-1] - K_real[T] - initial_spread
    for j in range(0, S.shape[1]-1): #0~11 (1~12)
        for i in range(0, 2**(S.shape[1]-1-(j+1))): # 0~2^11-1/2^0(1~2^11/2^1)
            V_call[i][S.shape[1]-1-(j+1)] = (0.5 * V_call[2*i][S.shape[1]-1-j] + 0.5 * V_call[2*i+1][S.shape[1]-1-j]) / np.exp(R_real.iloc[T-j,0])
            V_put[i][S.shape[1]-1-(j+1)] = (0.5 * V_put[2*i][S.shape[1]-1-j] + 0.5 * V_put[2*i+1][S.shape[1]-1-j]) / np.exp(R_real.iloc[T-j,0])
            ### Calculate V(when early exercise is True)
            if early_exercise:
                V_early[i][S.shape[1]-1-(j+1)] = S[i][S.shape[1]-1-(j+1)] - K_real[T-(j+1)] - initial_spread
                if V_early[i][S.shape[1]-1-(j+1)] < V_call[i][S.shape[1]-1-(j+1)]:
                    V_call[i][S.shape[1]-1-(j+1)] = V_early[i][S.shape[1]-1-(j+1)]
                    Time_call_early = j+1
                if V_early[i][S.shape[1]-1-(j+1)] > V_put[i][S.shape[1]-1-(j+1)]:
                    V_put[i][S.shape[1]-1-(j+1)] = V_early[i][S.shape[1]-1-(j+1)]
                    Time_put_early = j+1
    return V_call, V_put, Time_call_early, Time_put_early

# Summary of One Column Spread
def Spread_OneColumn(S_real, K_real, R_real, start, end, interval, early_exercise):
    # Checking bound of input range
    initial = (pd.to_datetime(start).year - S_real.index[0].year) * 12 + pd.to_datetime(start).month - 1
    final = (pd.to_datetime(end).year - S_real.index[0].year) * 12 + pd.to_datetime(end).month - 1
    if (final - initial) < interval:
        print('Out of Bound!!!')
    # Calculate S and V
    V_final = []
    early_call = []
    early_put = []
    for t in range(initial, final, interval):
        T = t + interval
        ### Calculate S
        S = S_generator(S_real, t, T)
        ### Calculate V
        V_call, V_put, Time_call_early, Time_put_early = V_generator_simple(S_real, S, K_real, R_real, t, T, early_exercise)
        V_final.append([V_call[0][0], V_put[0][0]])
        ### Calculate dates of early exercises
        if Time_call_early == 0:
            early_call.append(0)
        else:
            early_call.append(S_real.index[T-Time_call_early])
        if Time_put_early == 0:
            early_put.append(0)
        else:
            early_put.append(S_real.index[T-Time_put_early])
    # Results
    Time_early_exercise = pd.concat([pd.DataFrame(early_call, columns=['Early Exercise of Call']),
                                     pd.DataFrame(early_put, columns=['Early Exercise of Put'])], axis=1)
    V_final = pd.DataFrame(V_final, columns=['V(Call)', 'V(Put)'])
    return V_final, Time_early_exercise

# Summary of Full Column Spread
def Spread_FullColumns(S_real_full, K_real_full, R_real, start, end, interval, early_exercise):
    Spread_full = dict()
    Time_early_full = dict()
    R_real = R_real.copy()
    for target in tqdm(S_real_full.keys()):
        S_real = S_real_full[target]
        K_real = K_real_full[target.replace('(HPI)', '(JDI)')]
        Spread, Time_early = Spread_OneColumn(S_real, K_real, R_real, start, end, interval, early_exercise)
        Spread_full[target] = Spread
        Time_early_full[target] = Time_early
    return Spread_full, Time_early_full

# Summary of Full Result Statistics
def Summary_Result_Full(Result, Apartments_col, Detached_Houses_col, Row_Houses_col):
    print('Absolute Bubble Statistics in Full Period')
    result_summary = pd.DataFrame()
    for each in [Apartments_col, Detached_Houses_col, Row_Houses_col]:
        result_table = pd.concat([abs(Result[each]).mean(), abs(Result[each]).max(), 
                                  (abs(Result[each]).max()/abs(Result[each]).mean()-1)*100,
                                  abs(Result[each]).min(),
                                  (abs(Result[each]).min()/abs(Result[each]).mean()-1)*100], axis=1)
        result_table.columns = ['Average', 'Max', 'Max(%)', 'Min', 'Min(%)']
        result_summary = pd.concat([result_summary, pd.DataFrame(result_table.mean(), columns=[result_table.index[0].split(":")[1]]).T], axis=0)
        result_table = result_table.style.format({'Max(%)':'({:.0f}%)', 'Min(%)':'({:.0f}%)'})
        display(result_table)
    result_summary = result_summary.style.format({'Max(%)':'({:.0f}%)', 'Min(%)':'({:.0f}%)'})
    display(result_summary)
    print('Real Bubble Statistics in Full Period')
    result_summary = pd.DataFrame()
    for each in [Apartments_col, Detached_Houses_col, Row_Houses_col]:
        result_table = pd.concat([Result[each].mean(), Result[each].max(), Result[each].min(),
                            abs(Result[each].min()/Result[each].max())*100], axis=1)
        result_table.columns = ['Average', 'Max', 'Min', 'abs(Min/Max)(%)']
        result_summary = pd.concat([result_summary, pd.DataFrame(result_table.mean(), columns=[result_table.index[0].split(":")[1]]).T], axis=0)
        result_table = result_table.style.format({'abs(Min/Max)(%)':'({:.0f}%)'})
        display(result_table)  
    result_summary = result_summary.style.format({'abs(Min/Max)(%)':'({:.0f}%)'})
    display(result_summary)

# Summary of Trend Result Statistics
def Summary_Result_Trend(Result, Apartments_col, Detached_Houses_col, Row_Houses_col, windows=5):
    print('Absolute Bubble Statistics in Some periods')
    result_summary = pd.DataFrame()
    for each in [Apartments_col, Detached_Houses_col, Row_Houses_col]:
        result_table_concat = pd.DataFrame()
        for i in range(0,len(Result),windows):
            result_sub = Result.iloc[i:i+windows,:]
            result_table = pd.concat([abs(result_sub[each]).mean(), abs(result_sub[each]).max(), 
                                      (abs(result_sub[each]).max()/abs(result_sub[each]).mean()-1)*100,
                                      abs(result_sub[each]).min(),
                                      (abs(result_sub[each]).min()/abs(result_sub[each]).mean()-1)*100], axis=1)
            result_table_concat = pd.concat([result_table_concat, result_table], axis=1)
        result_summary = pd.concat([result_summary, pd.DataFrame(result_table_concat.mean(), columns=[result_table_concat.index[0].split(":")[1]]).T], axis=0)
        result_table_concat.columns = pd.MultiIndex.from_product([['2004~2008', '2009~2013', '2014~2018'],
                                                                  ['Average', 'Max', 'Max(%)', 'Min', 'Min(%)']])
        result_table_concat = result_table_concat.style.format({('2004~2008', 'Max(%)'):'({:.0f}%)', ('2004~2008', 'Min(%)'):'({:.0f}%)',
                                                                ('2009~2013', 'Max(%)'):'({:.0f}%)', ('2009~2013', 'Min(%)'):'({:.0f}%)',
                                                                ('2014~2018', 'Max(%)'):'({:.0f}%)', ('2014~2018', 'Min(%)'):'({:.0f}%)'})
        display(result_table_concat)
    result_summary.columns = pd.MultiIndex.from_product([['2004~2008', '2009~2013', '2014~2018'],
                                                         ['Average', 'Max', 'Max(%)', 'Min', 'Min(%)']])
    result_summary = result_summary.style.format({('2004~2008', 'Max(%)'):'({:.0f}%)', ('2004~2008', 'Min(%)'):'({:.0f}%)',
                                                  ('2009~2013', 'Max(%)'):'({:.0f}%)', ('2009~2013', 'Min(%)'):'({:.0f}%)',
                                                  ('2014~2018', 'Max(%)'):'({:.0f}%)', ('2014~2018', 'Min(%)'):'({:.0f}%)'})
    display(result_summary)
    print('Real Bubble Statistics in Some periods')
    result_summary = pd.DataFrame()
    for each in [Apartments_col, Detached_Houses_col, Row_Houses_col]:
        result_table_concat = pd.DataFrame()
        for i in range(0,len(Result),windows):
            result_sub = Result.iloc[i:i+windows,:]
            result_table = pd.concat([result_sub[each].mean(), result_sub[each].max(), result_sub[each].min(),
                                abs(result_sub[each].min()/result_sub[each].max())*100], axis=1)
            result_table_concat = pd.concat([result_table_concat, result_table], axis=1)
        result_summary = pd.concat([result_summary, pd.DataFrame(result_table_concat.mean(), columns=[result_table_concat.index[0].split(":")[1]]).T], axis=0)
        result_table_concat.columns = pd.MultiIndex.from_product([['2004~2008', '2009~2013', '2014~2018'],
                                                                  ['Average', 'Max', 'Min', 'abs(Min/Max)(%)']])
        result_table_concat = result_table_concat.style.format({('2004~2008', 'abs(Min/Max)(%)'):'({:.0f}%)',
                                                                ('2009~2013', 'abs(Min/Max)(%)'):'({:.0f}%)',
                                                                ('2014~2018', 'abs(Min/Max)(%)'):'({:.0f}%)'})
        display(result_table_concat)
    result_summary.columns = pd.MultiIndex.from_product([['2004~2008', '2009~2013', '2014~2018'],
                                                         ['Average', 'Max', 'Min', 'abs(Min/Max)(%)']])
    result_summary = result_summary.style.format({('2004~2008', 'abs(Min/Max)(%)'):'({:.0f}%)',
                                                  ('2009~2013', 'abs(Min/Max)(%)'):'({:.0f}%)',
                                                  ('2014~2018', 'abs(Min/Max)(%)'):'({:.0f}%)'})
    display(result_summary)
    
# Calculate Rowsum of Data by Windows
def rowsum_bywindow(Target, windows):
    result_rowsum = pd.DataFrame()
    for i in range(int((Target.shape[0]+1)/windows)):
        result_rowsum = pd.concat([result_rowsum, pd.DataFrame(Target.iloc[i*windows:i*windows+2,:].sum()).T], axis=0)
    result_rowsum.index = [n for n in range(i+1)]
    return result_rowsum

# Calculate Arbitrage Opportunity
def Arbitrage_Calculator(Result_12M, Result_6M):
    arbitrage_value, arbitrage_count = pd.DataFrame(), pd.DataFrame()
    for col in Result_12M.columns:
        spread_bywindow = pd.concat([Result_12M[col].shift(1), Result_6M[col].shift(1), Result_6M[col], Result_12M[col]], axis=1)
        max_TF, min_TF = pd.DataFrame(), pd.DataFrame()
        for i in range(spread_bywindow.shape[0]):
            max_TF = pd.concat([max_TF, pd.DataFrame(spread_bywindow[spread_bywindow > 0].iloc[i,:] == spread_bywindow[spread_bywindow > 0].max(axis=1)[i]).T], axis=0)
            min_TF = pd.concat([min_TF, pd.DataFrame(spread_bywindow[spread_bywindow < 0].iloc[i,:] == spread_bywindow[spread_bywindow < 0].min(axis=1)[i]).T], axis=0)
        arbitrage_count = pd.concat([arbitrage_count,
                                     pd.DataFrame([list(max_TF.sum(axis=0))[0]+list(max_TF.sum(axis=0))[3],
                                                   list(max_TF.sum(axis=0))[1]+list(max_TF.sum(axis=0))[2],
                                                   list(min_TF.sum(axis=0))[1]+list(min_TF.sum(axis=0))[2],
                                                   list(min_TF.sum(axis=0))[0]+list(min_TF.sum(axis=0))[3]],
                                                  columns=[col], index = ['Arbitrage_12M(Short)', 'Arbitrage_6M(Short)', 'Arbitrage_6M(Long)', 'Arbitrage_12M(Long)']).T], axis=0)
        arbitrage_value = pd.concat([arbitrage_value,
                                     pd.DataFrame([(list(spread_bywindow[max_TF].sum(axis=0))[0]+list(spread_bywindow[max_TF].sum(axis=0))[3]),
                                                   (list(spread_bywindow[max_TF].sum(axis=0))[1]+list(spread_bywindow[max_TF].sum(axis=0))[2]),
                                                   (list(spread_bywindow[min_TF].sum(axis=0))[1]+list(spread_bywindow[min_TF].sum(axis=0))[2]),
                                                   (list(spread_bywindow[min_TF].sum(axis=0))[0]+list(spread_bywindow[min_TF].sum(axis=0))[3])],
                                                  columns=[col], index = ['Arbitrage_12M(Short)', 'Arbitrage_6M(Short)', 'Arbitrage_6M(Long)', 'Arbitrage_12M(Long)']).T], axis=0)
    arbitrage_value = (arbitrage_value/arbitrage_count).fillna(0)
    return arbitrage_count, arbitrage_value

# Summary Arbitrage Count and Value
def Summary_Arbitrage(arbi_nonearly_count, arbi_nonearly_value, arbi_earlylong_count, arbi_earlylong_value, arbi_earlyshort_count, arbi_earlyshort_value):
    print('Summary of Arbitrage Trend in Count and Value')
    arbi_count_full = pd.DataFrame()
    arbi_count_full = pd.concat([arbi_count_full, pd.DataFrame(arbi_nonearly_count.mean(axis=0)).T])
    arbi_count_full = pd.concat([arbi_count_full, pd.DataFrame(arbi_earlylong_count.mean(axis=0)).T + pd.DataFrame(arbi_earlyshort_count.mean(axis=0)).T])
    arbi_value_full = pd.DataFrame()
    arbi_value_full = pd.concat([arbi_value_full, pd.DataFrame(arbi_nonearly_value.mean(axis=0)).T])
    arbi_value_full = pd.concat([arbi_value_full, pd.DataFrame(arbi_earlylong_value.mean(axis=0)).T + pd.DataFrame(arbi_earlyshort_value.mean(axis=0)).T])
    for col in [Apartments_Scol, Detached_Houses_Scol, Row_Houses_Scol]:
        arbi_count_full = pd.concat([arbi_count_full, pd.DataFrame(arbi_nonearly_count.loc[col].mean(axis=0)).T])
        arbi_count_full = pd.concat([arbi_count_full, pd.DataFrame(arbi_earlylong_count.loc[col].mean(axis=0)).T + pd.DataFrame(arbi_earlyshort_count.loc[col].mean(axis=0)).T])
        arbi_value_full = pd.concat([arbi_value_full, pd.DataFrame(arbi_nonearly_value.loc[col].mean(axis=0)).T])
        arbi_value_full = pd.concat([arbi_value_full, pd.DataFrame(arbi_earlylong_value.loc[col].mean(axis=0)).T + pd.DataFrame(arbi_earlyshort_value.loc[col].mean(axis=0)).T])
    arbi_count_full.index = ['All Types', 'All Types(early)', 'Apartments', 'Apartments(early)', 'Detached_Houses', 'Detached_Houses(early)', 'Row_Houses', 'Row_Houses(early)']
    arbi_value_full.index = ['All Types', 'All Types(early)', 'Apartments', 'Apartments(early)', 'Detached_Houses', 'Detached_Houses(early)', 'Row_Houses', 'Row_Houses(early)']
    display(arbi_count_full, arbi_value_full)
    display(arbi_nonearly_count, arbi_nonearly_value, arbi_earlylong_count+arbi_earlyshort_count, arbi_earlylong_value+arbi_earlyshort_value)

# %% [markdown]
# # Main
# 1) 만원단위 절삭: Index 나누기 10000
# 2) Return 변환: (log(t)-log(t-1))으로 Return 변환 -> 첫줄(NaN)은 Return 평균값 대체
# 3) Conditional Volatility 계산: Return*100으로 ARIMA(1,1) + GARCH(1,1) 적용
# 4) Stochastic Parameters of S 정리:
# => HPI / Return / Mu / CVol(위CVol나누기100) / Nu / Up_return / Down_return
# 5) S 트리노미얼 트리 확장
# 6) V 트리노미얼 트리 확장
# 7) 조기행사 조건부 트리 업데이트

# %%
# Data Loading
location = 'C:\\Users\\KK\\Desktop\\20190104_KB주택가격동향_KK.xlsx'
raw_HPI = pd.read_excel(location, sheet_name='Raw_HPI_value')
raw_JDI = pd.read_excel(location, sheet_name='Raw_JDI_value')
raw_IR = pd.read_excel(location, sheet_name='Raw_IR')
raw_IR.columns = ['Time', 'Interest_Rate']
raw_IR = raw_IR.iloc[3:,:]

# Indexing and Drop
raw_HPI.set_index(pd.date_range('1986-01', '2019-01', freq='M'), inplace=True)
raw_JDI.set_index(pd.date_range('1986-01', '2019-01', freq='M'), inplace=True)
raw_IR.set_index(pd.date_range('1987-01', '2019-01', freq='M'), inplace=True)
del raw_HPI['Time']
del raw_JDI['Time']
del raw_IR['Time']

# Time & Null Filter
raw_HPI = raw_HPI.loc[raw_HPI.index >= '2004-01', raw_HPI.isna().sum() == 0]
raw_JDI = raw_JDI.loc[raw_JDI.index >= '2004-01', raw_JDI.isna().sum() == 0]
raw_JDI.loc['2019-01-31'] = raw_JDI.iloc[len(raw_JDI)-1]
raw_IR = raw_IR[raw_IR.index >= '2004-01'] / (100*12) # Transfer to Monthly IR
raw_IR = pd.DataFrame(raw_IR.Interest_Rate.astype('float'))
raw_IR.loc['2019-01-31'] = raw_IR.values.flatten()[len(raw_IR)-1]

# Index to Return
raw_HPI_return = index_to_return(raw_HPI)

# Calulate Conditional Volatility
raw_HPI_cvol = conditional_volatility(raw_HPI_return)

# Rearrange of Stochastic Parameters
raw_HPI_parameters = get_stochastic_parameters(raw_HPI, raw_HPI_return, raw_HPI_cvol)

# Grouping of Columns
Apartments_Scol, Apartments_Kcol, Detached_Houses_Scol, Detached_Houses_Kcol, Row_Houses_Scol, Row_Houses_Kcol = Grouping(raw_HPI_parameters)

# Calculate S & V value
# Spread, Time_early = Spread_OneColumn(raw_HPI_parameters['Seoul:Apartments(HPI)'], raw_JDI['Seoul:Apartments(JDI)'], raw_IR,
#                                       start = '2004-01', end = '2018-12', interval = 12, early_exercise = False)
print('Processing of spread calculation without early exercise')
print('Trading by 12 months')
Spreadfull, Time_early_full = Spread_FullColumns(raw_HPI_parameters, raw_JDI, raw_IR,
                                                 start = '2004-01', end = '2018-12', interval = 12, early_exercise = False)
print('Trading by 6 months')
Spreadfull_by6, Time_early_full_by6 = Spread_FullColumns(raw_HPI_parameters, raw_JDI, raw_IR,
                                                 start = '2004-01', end = '2018-12', interval = 6, early_exercise = False)
print('Processing of spread calculation with early exercise')
print('Trading by 12 months')
Spreadfull_early, Time_early_full = Spread_FullColumns(raw_HPI_parameters, raw_JDI, raw_IR,
                                                 start = '2004-01', end = '2018-12', interval = 12, early_exercise = True)
print('Trading by 6 months')
Spreadfull_early_by6, Time_early_full_by6 = Spread_FullColumns(raw_HPI_parameters, raw_JDI, raw_IR,
                                                 start = '2004-01', end = '2018-12', interval = 6, early_exercise = True)
# Out:
# Processing of spread calculation without early exercise
# Trading by 12 months
# 100%|██████████████████████████████████████████████████████████████████████████████████| 25/25 [03:19<00:00,  8.14s/it]
# Trading by 6 months
# 100%|██████████████████████████████████████████████████████████████████████████████████| 25/25 [00:06<00:00,  3.14it/s]
# Processing of spread calculation with early exercise
# Trading by 12 months
# 100%|██████████████████████████████████████████████████████████████████████████████████| 25/25 [04:00<00:00,  9.75s/it]
# Trading by 6 months
# 100%|██████████████████████████████████████████████████████████████████████████████████| 25/25 [00:07<00:00,  3.20it/s]

# %% [markdown]
# # Summary Result

# %%
# Summary Statistics (by all and types)
Summary_AllGroup(raw_HPI, raw_JDI, Apartments_Scol, Detached_Houses_Scol, Row_Houses_Scol, Apartments_Kcol, Detached_Houses_Kcol, Row_Houses_Kcol)
result_IR = summary_statistics(raw_IR*100*12) # For the Transfered Yearly IR
display(result_IR.iloc[:4,:].T)

# Summary Statistics of HPI Returns
display(summary_statistics(raw_HPI_return[Apartments_Scol]))
display(summary_statistics(raw_HPI_return[Detached_Houses_Scol]))
display(summary_statistics(raw_HPI_return[Row_Houses_Scol]))

# Arrange of Results
result, result_by6 = pd.DataFrame(), pd.DataFrame()
for key in Spreadfull.keys():
    result = pd.concat([result, Spreadfull[key]['V(Call)']], axis=1)
    result_by6 = pd.concat([result_by6, Spreadfull_by6[key]['V(Call)']], axis=1)
result_by6 = rowsum_bywindow(result_by6, 2)
result.columns, result_by6.columns = Spreadfull.keys(), Spreadfull_by6.keys()
result_call, result_call_by6 = pd.DataFrame(), pd.DataFrame()
for key in Spreadfull_early.keys():
    result_call = pd.concat([result_call, Spreadfull_early[key]['V(Call)']], axis=1)
    result_call_by6 = pd.concat([result_call_by6, Spreadfull_early_by6[key]['V(Call)']], axis=1)
result_call_by6 = rowsum_bywindow(result_call_by6, 2)
result_call.columns, result_call_by6.columns = Spreadfull_early.keys(), Spreadfull_early_by6.keys()
result_put, result_put_by6 = pd.DataFrame(), pd.DataFrame()
for key in Spreadfull_early.keys():
    result_put = pd.concat([result_put, Spreadfull_early[key]['V(Put)']], axis=1)
    result_put_by6 = pd.concat([result_put_by6, Spreadfull_early_by6[key]['V(Put)']], axis=1)
result_put_by6 = rowsum_bywindow(result_put_by6, 2)
result_put.columns, result_put_by6.columns = Spreadfull_early.keys(), Spreadfull_early_by6.keys()

# Bubble Statistics
Summary_Result_Full(result, Apartments_Scol, Detached_Houses_Scol, Row_Houses_Scol)

# Bubble Statistics (by trend)
Summary_Result_Trend(result, Apartments_Scol, Detached_Houses_Scol, Row_Houses_Scol, windows=5)

# Bubble Statistics when early exercises
Summary_Result_Full(result_call, Apartments_Scol, Detached_Houses_Scol, Row_Houses_Scol)
Summary_Result_Full(result_put, Apartments_Scol, Detached_Houses_Scol, Row_Houses_Scol)

# Bubble Statistics when early exercises (by trend)
Summary_Result_Trend(result_call, Apartments_Scol, Detached_Houses_Scol, Row_Houses_Scol, windows=5)
Summary_Result_Trend(result_put, Apartments_Scol, Detached_Houses_Scol, Row_Houses_Scol, windows=5)

# Arbitrage Opportunity
arbi_nonearly_count, arbi_nonearly_value = Arbitrage_Calculator(result, result_by6)
arbi_earlylong_count, arbi_earlylong_value = Arbitrage_Calculator(result_call, result_call_by6)
arbi_earlyshort_count, arbi_earlyshort_value = Arbitrage_Calculator(result_put, result_put_by6)
Summary_Arbitrage(arbi_nonearly_count, arbi_nonearly_value, arbi_earlylong_count, arbi_earlylong_value, arbi_earlyshort_count, arbi_earlyshort_value)
# Out:
# Summary Statistics
#           Apartments(HPI)  Apartments(JDI)  Detached_Houses(HPI)  \
# Mean            27,504.10        16,792.87             49,197.73
# Stdev            3,957.08         3,966.40              5,068.73
# Skewness            -0.26             0.08                 -0.50
# Kurtosis            -1.04            -1.64                 -0.59
#
#           Detached_Houses(JDI)  Row_Houses(HPI)  Row_Houses(JDI)
# Mean                 20,566.24        17,783.43        10,873.09
# Stdev                 2,525.89         2,183.69         1,979.84
# Skewness                  0.03            -0.85            -0.03
# Kurtosis                 -1.35            -0.57            -1.43
#                                            Mean    Stdev  Skewness  Kurtosis
# Seoul:Apartments(HPI)                 62,638.21 7,878.61     -0.68      0.50
# Northern Seoul:Apartments(HPI)        46,736.65 6,149.53     -0.74     -0.06
# Southern Seoul:Apartments(HPI)        76,030.43 9,351.33     -0.61      0.90
# 6 Large Cities:Apartments(HPI)        21,739.38 3,960.62      0.08     -1.62
# Gyeonggi-do:Apartments(HPI)           31,545.54 3,408.66     -1.35      0.56
# Gangwon-do:Apartments(HPI)            14,406.90 2,107.30      0.14     -1.69
# Chungcheongbuk-do:Apartments(HPI)     13,389.09 2,797.54      0.06     -1.75
# Chungcheongnam-do:Apartments(HPI)     15,676.47 2,240.56      0.20     -1.80
# Jeollabuk-do:Apartments(HPI)          14,939.69 2,827.86     -0.33     -1.62
# Jeollanam-do:Apartments(HPI)          13,982.16 1,948.61     -0.21     -1.73
# Gyeongsangbuk-do:Apartments(HPI)      13,911.59 2,529.06      0.28     -1.55
# Gyeongsangnam-do:Apartments(HPI)      17,121.54 3,457.71     -0.13     -1.85
# Non-Metropolitan Area:Apartments(HPI) 15,435.61 2,784.64     -0.06     -1.80
#                                            Mean    Stdev  Skewness  Kurtosis
# Seoul:Apartments(JDI)                 32,992.25 8,294.27      0.25     -1.40
# Northern Seoul:Apartments(JDI)        26,667.69 6,577.82      0.25     -1.37
# Southern Seoul:Apartments(JDI)        38,360.04 9,790.66      0.25     -1.42
# 6 Large Cities:Apartments(JDI)        15,137.67 3,452.62      0.09     -1.70
# Gyeonggi-do:Apartments(JDI)           18,904.15 4,779.61      0.16     -1.47
# Gangwon-do:Apartments(JDI)            11,085.44 2,124.48      0.20     -1.74
# Chungcheongbuk-do:Apartments(JDI)      9,809.98 2,491.46      0.06     -1.80
# Chungcheongnam-do:Apartments(JDI)     10,824.90 2,655.17      0.16     -1.78
# Jeollabuk-do:Apartments(JDI)          11,232.62 2,272.10     -0.30     -1.62
# Jeollanam-do:Apartments(JDI)          10,177.87 1,860.66     -0.23     -1.74
# Gyeongsangbuk-do:Apartments(JDI)      10,396.41 2,088.30      0.23     -1.68
# Gyeongsangnam-do:Apartments(JDI)      11,737.13 2,758.61     -0.12     -1.81
# Non-Metropolitan Area:Apartments(JDI) 10,981.11 2,417.44     -0.02     -1.78
#                                                 Mean    Stdev  Skewness  \
# Seoul:Detached_Houses(HPI)                 68,115.46 8,091.99     -0.90
# Northern Seoul:Detached_Houses(HPI)        60,182.45 7,185.91     -0.93
# Southern Seoul:Detached_Houses(HPI)        80,711.96 9,529.00     -0.85
# 6 Large Cities:Detached_Houses(HPI)        23,590.61 1,879.73      0.48
# Gyeonggi-do:Detached_Houses(HPI)           44,836.42 2,875.84     -1.30
# Non-Metropolitan Area:Detached_Houses(HPI) 17,749.51   849.92      0.50
#
#                                             Kurtosis
# Seoul:Detached_Houses(HPI)                     -0.44
# Northern Seoul:Detached_Houses(HPI)            -0.41
# Southern Seoul:Detached_Houses(HPI)            -0.50
# 6 Large Cities:Detached_Houses(HPI)            -1.13
# Gyeonggi-do:Detached_Houses(HPI)                0.17
# Non-Metropolitan Area:Detached_Houses(HPI)     -1.23
#                                                 Mean    Stdev  Skewness  \
# Seoul:Detached_Houses(JDI)                 27,606.44 3,868.53     -0.05
# Northern Seoul:Detached_Houses(JDI)        24,732.88 3,512.08     -0.03
# Southern Seoul:Detached_Houses(JDI)        32,224.17 4,426.08     -0.08
# 6 Large Cities:Detached_Houses(JDI)        10,222.93   915.20      0.41
# Gyeonggi-do:Detached_Houses(JDI)           20,267.14 1,805.45     -0.27
# Non-Metropolitan Area:Detached_Houses(JDI)  8,343.91   628.00      0.17
#
#                                             Kurtosis
# Seoul:Detached_Houses(JDI)                     -1.29
# Northern Seoul:Detached_Houses(JDI)            -1.23
# Southern Seoul:Detached_Houses(JDI)            -1.39
# 6 Large Cities:Detached_Houses(JDI)            -1.38
# Gyeonggi-do:Detached_Houses(JDI)               -1.19
# Non-Metropolitan Area:Detached_Houses(JDI)     -1.60
#                                            Mean    Stdev  Skewness  Kurtosis
# Seoul:Row_Houses(HPI)                 24,657.47 2,959.57     -1.11     -0.25
# Northern Seoul:Row_Houses(HPI)        22,169.28 2,725.39     -1.08     -0.37
# Southern Seoul:Row_Houses(HPI)        27,240.82 3,191.76     -1.13     -0.10
# 6 Large Cities:Row_Houses(HPI)        10,042.59 1,314.74     -0.59     -1.10
# Gyeonggi-do:Row_Houses(HPI)           14,462.48 2,013.83     -1.32      0.05
# Non-Metropolitan Area:Row_Houses(HPI)  8,127.94   896.85      0.16     -1.68
#                                            Mean    Stdev  Skewness  Kurtosis
# Seoul:Row_Houses(JDI)                 14,650.19 2,833.27      0.04     -1.38
# Northern Seoul:Row_Houses(JDI)        13,564.34 2,653.73      0.04     -1.35
# Southern Seoul:Row_Houses(JDI)        15,788.89 3,014.41      0.04     -1.41
# 6 Large Cities:Row_Houses(JDI)         6,654.70 1,007.61     -0.16     -1.49
# Gyeonggi-do:Row_Houses(JDI)            8,936.56 1,600.41     -0.28     -1.30
# Non-Metropolitan Area:Row_Houses(JDI)  5,643.83   769.62      0.13     -1.67
#                Mean  Stdev  Skewness  Kurtosis
# Interest_Rate  4.06   1.54      0.38     -0.45
#                          Seoul:Apartments(HPI)  \
# Mean                                      0.00
# Stdev                                     0.01
# Skewness                                  2.91
# Kurtosis                                 15.09
# Kolmogorov–Smirnov                        0.49
# (p-value)                                 0.00
# Jarque–Bera                           1,858.11
# (p-value)                                 0.00
# ARCH(10)                                 33.14
# (p-value)                                 0.00
# ARCH(20)                                 36.20
# (p-value)                                 0.01
# Ljung–Box(10)                           177.43
# (p-value)                                 0.00
# Ljung–Box(20)                           256.01
# (p-value)                                 0.00
# Ljung–Box(10)^2                          38.76
# (p-value)                                 0.00
# Ljung–Box(20)^2                          48.58
# (p-value)                                 0.00
# Augmented Dickey–Fuller                  -6.16
# (p-value)                                 0.00
#
#                          Northern Seoul:Apartments(HPI)  \
# Mean                                               0.00
# Stdev                                              0.01
# Skewness                                           3.74
# Kurtosis                                          19.28
# Kolmogorov–Smirnov                                 0.49
# (p-value)                                          0.00
# Jarque–Bera                                    3,040.15
# (p-value)                                          0.00
# ARCH(10)                                          76.58
# (p-value)                                          0.00
# ARCH(20)                                          77.99
# (p-value)                                          0.00
# Ljung–Box(10)                                    174.90
# (p-value)                                          0.00
# Ljung–Box(20)                                    276.57
# (p-value)                                          0.00
# Ljung–Box(10)^2                                   68.58
# (p-value)                                          0.00
# Ljung–Box(20)^2                                   87.76
# (p-value)                                          0.00
# Augmented Dickey–Fuller                           -5.02
# (p-value)                                          0.00
#
#                          Southern Seoul:Apartments(HPI)  \
# Mean                                               0.00
# Stdev                                              0.01
# Skewness                                           2.55
# Kurtosis                                          11.54
# Kolmogorov–Smirnov                                 0.49
# (p-value)                                          0.00
# Jarque–Bera                                    1,130.76
# (p-value)                                          0.00
# ARCH(10)                                          25.96
# (p-value)                                          0.00
# ARCH(20)                                          33.33
# (p-value)                                          0.03
# Ljung–Box(10)                                    178.45
# (p-value)                                          0.00
# Ljung–Box(20)                                    216.70
# (p-value)                                          0.00
# Ljung–Box(10)^2                                   39.02
# (p-value)                                          0.00
# Ljung–Box(20)^2                                   52.64
# (p-value)                                          0.00
# Augmented Dickey–Fuller                           -5.94
# (p-value)                                          0.00
#
#                          6 Large Cities:Apartments(HPI)  \
# Mean                                               0.00
# Stdev                                              0.00
# Skewness                                           1.85
# Kurtosis                                           5.11
# Kolmogorov–Smirnov                                 0.50
# (p-value)                                          0.00
# Jarque–Bera                                      283.66
# (p-value)                                          0.00
# ARCH(10)                                         139.32
# (p-value)                                          0.00
# ARCH(20)                                         133.81
# (p-value)                                          0.00
# Ljung–Box(10)                                    441.48
# (p-value)                                          0.00
# Ljung–Box(20)                                    445.90
# (p-value)                                          0.00
# Ljung–Box(10)^2                                  377.43
# (p-value)                                          0.00
# Ljung–Box(20)^2                                  378.79
# (p-value)                                          0.00
# Augmented Dickey–Fuller                           -3.87
# (p-value)                                          0.00
#
#                          Gyeonggi-do:Apartments(HPI)  \
# Mean                                            0.00
# Stdev                                           0.01
# Skewness                                        4.83
# Kurtosis                                       37.45
# Kolmogorov–Smirnov                              0.49
# (p-value)                                       0.00
# Jarque–Bera                                10,614.09
# (p-value)                                       0.00
# ARCH(10)                                       23.06
# (p-value)                                       0.01
# ARCH(20)                                       22.78
# (p-value)                                       0.30
# Ljung–Box(10)                                 169.44
# (p-value)                                       0.00
# Ljung–Box(20)                                 222.22
# (p-value)                                       0.00
# Ljung–Box(10)^2                                26.08
# (p-value)                                       0.00
# Ljung–Box(20)^2                                28.64
# (p-value)                                       0.10
# Augmented Dickey–Fuller                        -6.16
# (p-value)                                       0.00
#
#                          Gangwon-do:Apartments(HPI)  \
# Mean                                           0.00
# Stdev                                          0.01
# Skewness                                       4.33
# Kurtosis                                      31.29
# Kolmogorov–Smirnov                             0.50
# (p-value)                                      0.00
# Jarque–Bera                                7,484.37
# (p-value)                                      0.00
# ARCH(10)                                      23.54
# (p-value)                                      0.01
# ARCH(20)                                      22.24
# (p-value)                                      0.33
# Ljung–Box(10)                                351.49
# (p-value)                                      0.00
# Ljung–Box(20)                                354.80
# (p-value)                                      0.00
# Ljung–Box(10)^2                               42.79
# (p-value)                                      0.00
# Ljung–Box(20)^2                               43.98
# (p-value)                                      0.00
# Augmented Dickey–Fuller                       -3.03
# (p-value)                                      0.03
#
#                          Chungcheongbuk-do:Apartments(HPI)  \
# Mean                                                  0.00
# Stdev                                                 0.01
# Skewness                                              1.17
# Kurtosis                                              3.51
# Kolmogorov–Smirnov                                    0.49
# (p-value)                                             0.00
# Jarque–Bera                                         126.03
# (p-value)                                             0.00
# ARCH(10)                                            101.71
# (p-value)                                             0.00
# ARCH(20)                                            100.11
# (p-value)                                             0.00
# Ljung–Box(10)                                       709.02
# (p-value)                                             0.00
# Ljung–Box(20)                                       823.58
# (p-value)                                             0.00
# Ljung–Box(10)^2                                     357.66
# (p-value)                                             0.00
# Ljung–Box(20)^2                                     362.17
# (p-value)                                             0.00
# Augmented Dickey–Fuller                              -2.08
# (p-value)                                             0.25
#
#                          Chungcheongnam-do:Apartments(HPI)  \
# Mean                                                  0.00
# Stdev                                                 0.00
# Skewness                                              1.03
# Kurtosis                                              1.27
# Kolmogorov–Smirnov                                    0.50
# (p-value)                                             0.00
# Jarque–Bera                                          42.36
# (p-value)                                             0.00
# ARCH(10)                                             86.35
# (p-value)                                             0.00
# ARCH(20)                                             94.91
# (p-value)                                             0.00
# Ljung–Box(10)                                       369.67
# (p-value)                                             0.00
# Ljung–Box(20)                                       536.01
# (p-value)                                             0.00
# Ljung–Box(10)^2                                     233.27
# (p-value)                                             0.00
# Ljung–Box(20)^2                                     259.10
# (p-value)                                             0.00
# Augmented Dickey–Fuller                              -1.51
# (p-value)                                             0.53
#
#                          Jeollabuk-do:Apartments(HPI)  \
# Mean                                             0.00
# Stdev                                            0.00
# Skewness                                         1.29
# Kurtosis                                         1.33
# Kolmogorov–Smirnov                               0.50
# (p-value)                                        0.00
# Jarque–Bera                                     60.65
# (p-value)                                        0.00
# ARCH(10)                                       108.80
# (p-value)                                        0.00
# ARCH(20)                                       106.29
# (p-value)                                        0.00
# Ljung–Box(10)                                  710.27
# (p-value)                                        0.00
# Ljung–Box(20)                                  817.96
# (p-value)                                        0.00
# Ljung–Box(10)^2                                458.37
# (p-value)                                        0.00
# Ljung–Box(20)^2                                499.45
# (p-value)                                        0.00
# Augmented Dickey–Fuller                         -2.70
# (p-value)                                        0.07
#
#                          Jeollanam-do:Apartments(HPI)  \
# Mean                                             0.00
# Stdev                                            0.00
# Skewness                                         2.29
# Kurtosis                                         8.62
# Kolmogorov–Smirnov                               0.50
# (p-value)                                        0.00
# Jarque–Bera                                    677.77
# (p-value)                                        0.00
# ARCH(10)                                        63.50
# (p-value)                                        0.00
# ARCH(20)                                        72.37
# (p-value)                                        0.00
# Ljung–Box(10)                                  490.95
# (p-value)                                        0.00
# Ljung–Box(20)                                  545.31
# (p-value)                                        0.00
# Ljung–Box(10)^2                                143.97
# (p-value)                                        0.00
# Ljung–Box(20)^2                                148.12
# (p-value)                                        0.00
# Augmented Dickey–Fuller                         -2.87
# (p-value)                                        0.05
#
#                          Gyeongsangbuk-do:Apartments(HPI)  \
# Mean                                                 0.00
# Stdev                                                0.00
# Skewness                                             0.32
# Kurtosis                                            -0.03
# Kolmogorov–Smirnov                                   0.50
# (p-value)                                            0.00
# Jarque–Bera                                          3.09
# (p-value)                                            0.21
# ARCH(10)                                            64.56
# (p-value)                                            0.00
# ARCH(20)                                            68.54
# (p-value)                                            0.00
# Ljung–Box(10)                                      759.76
# (p-value)                                            0.00
# Ljung–Box(20)                                    1,018.44
# (p-value)                                            0.00
# Ljung–Box(10)^2                                    210.02
# (p-value)                                            0.00
# Ljung–Box(20)^2                                    239.62
# (p-value)                                            0.00
# Augmented Dickey–Fuller                             -1.10
# (p-value)                                            0.71
#
#                          Gyeongsangnam-do:Apartments(HPI)  \
# Mean                                                 0.00
# Stdev                                                0.01
# Skewness                                             2.93
# Kurtosis                                            12.45
# Kolmogorov–Smirnov                                   0.50
# (p-value)                                            0.00
# Jarque–Bera                                      1,346.49
# (p-value)                                            0.00
# ARCH(10)                                           121.51
# (p-value)                                            0.00
# ARCH(20)                                           115.81
# (p-value)                                            0.00
# Ljung–Box(10)                                      645.37
# (p-value)                                            0.00
# Ljung–Box(20)                                      670.32
# (p-value)                                            0.00
# Ljung–Box(10)^2                                    239.70
# (p-value)                                            0.00
# Ljung–Box(20)^2                                    241.79
# (p-value)                                            0.00
# Augmented Dickey–Fuller                             -3.00
# (p-value)                                            0.03
#
#                          Non-Metropolitan Area:Apartments(HPI)
# Mean                                                      0.00
# Stdev                                                     0.00
# Skewness                                                  1.87
# Kurtosis                                                  5.02
# Kolmogorov–Smirnov                                        0.50
# (p-value)                                                 0.00
# Jarque–Bera                                             279.64
# (p-value)                                                 0.00
# ARCH(10)                                                138.97
# (p-value)                                                 0.00
# ARCH(20)                                                133.01
# (p-value)                                                 0.00
# Ljung–Box(10)                                           823.12
# (p-value)                                                 0.00
# Ljung–Box(20)                                           925.33
# (p-value)                                                 0.00
# Ljung–Box(10)^2                                         517.77
# (p-value)                                                 0.00
# Ljung–Box(20)^2                                         524.05
# (p-value)                                                 0.00
# Augmented Dickey–Fuller                                  -2.27
# (p-value)                                                 0.18
#                          Seoul:Detached_Houses(HPI)  \
# Mean                                           0.00
# Stdev                                          0.00
# Skewness                                       2.55
# Kurtosis                                      11.35
# Kolmogorov–Smirnov                             0.50
# (p-value)                                      0.00
# Jarque–Bera                                1,099.36
# (p-value)                                      0.00
# ARCH(10)                                      66.67
# (p-value)                                      0.00
# ARCH(20)                                      70.25
# (p-value)                                      0.00
# Ljung–Box(10)                                323.31
# (p-value)                                      0.00
# Ljung–Box(20)                                464.16
# (p-value)                                      0.00
# Ljung–Box(10)^2                               89.77
# (p-value)                                      0.00
# Ljung–Box(20)^2                              123.22
# (p-value)                                      0.00
# Augmented Dickey–Fuller                       -1.63
# (p-value)                                      0.47
#
#                          Northern Seoul:Detached_Houses(HPI)  \
# Mean                                                    0.00
# Stdev                                                   0.00
# Skewness                                                2.04
# Kurtosis                                                6.58
# Kolmogorov–Smirnov                                      0.50
# (p-value)                                               0.00
# Jarque–Bera                                           426.72
# (p-value)                                               0.00
# ARCH(10)                                               76.11
# (p-value)                                               0.00
# ARCH(20)                                               78.48
# (p-value)                                               0.00
# Ljung–Box(10)                                         348.04
# (p-value)                                               0.00
# Ljung–Box(20)                                         519.70
# (p-value)                                               0.00
# Ljung–Box(10)^2                                       117.73
# (p-value)                                               0.00
# Ljung–Box(20)^2                                       184.49
# (p-value)                                               0.00
# Augmented Dickey–Fuller                                -3.94
# (p-value)                                               0.00
#
#                          Southern Seoul:Detached_Houses(HPI)  \
# Mean                                                    0.00
# Stdev                                                   0.00
# Skewness                                                3.41
# Kurtosis                                               19.22
# Kolmogorov–Smirnov                                      0.50
# (p-value)                                               0.00
# Jarque–Bera                                         2,954.85
# (p-value)                                               0.00
# ARCH(10)                                               41.88
# (p-value)                                               0.00
# ARCH(20)                                               43.00
# (p-value)                                               0.00
# Ljung–Box(10)                                         186.55
# (p-value)                                               0.00
# Ljung–Box(20)                                         237.31
# (p-value)                                               0.00
# Ljung–Box(10)^2                                        49.07
# (p-value)                                               0.00
# Ljung–Box(20)^2                                        57.38
# (p-value)                                               0.00
# Augmented Dickey–Fuller                                -5.63
# (p-value)                                               0.00
#
#                          6 Large Cities:Detached_Houses(HPI)  \
# Mean                                                    0.00
# Stdev                                                   0.00
# Skewness                                               -0.91
# Kurtosis                                                2.86
# Kolmogorov–Smirnov                                      0.50
# (p-value)                                               0.00
# Jarque–Bera                                            80.62
# (p-value)                                               0.00
# ARCH(10)                                               72.43
# (p-value)                                               0.00
# ARCH(20)                                               78.93
# (p-value)                                               0.00
# Ljung–Box(10)                                         319.75
# (p-value)                                               0.00
# Ljung–Box(20)                                         324.73
# (p-value)                                               0.00
# Ljung–Box(10)^2                                       137.36
# (p-value)                                               0.00
# Ljung–Box(20)^2                                       154.00
# (p-value)                                               0.00
# Augmented Dickey–Fuller                                -3.69
# (p-value)                                               0.00
#
#                          Gyeonggi-do:Detached_Houses(HPI)  \
# Mean                                                 0.00
# Stdev                                                0.00
# Skewness                                             2.65
# Kurtosis                                            15.50
# Kolmogorov–Smirnov                                   0.50
# (p-value)                                            0.00
# Jarque–Bera                                      1,903.93
# (p-value)                                            0.00
# ARCH(10)                                            77.12
# (p-value)                                            0.00
# ARCH(20)                                            76.87
# (p-value)                                            0.00
# Ljung–Box(10)                                      234.75
# (p-value)                                            0.00
# Ljung–Box(20)                                      263.71
# (p-value)                                            0.00
# Ljung–Box(10)^2                                     78.37
# (p-value)                                            0.00
# Ljung–Box(20)^2                                     85.25
# (p-value)                                            0.00
# Augmented Dickey–Fuller                             -3.85
# (p-value)                                            0.00
#
#                          Non-Metropolitan Area:Detached_Houses(HPI)
# Mean                                                           0.00
# Stdev                                                          0.00
# Skewness                                                      -1.00
# Kurtosis                                                       3.16
# Kolmogorov–Smirnov                                             0.50
# (p-value)                                                      0.00
# Jarque–Bera                                                   98.51
# (p-value)                                                      0.00
# ARCH(10)                                                      36.32
# (p-value)                                                      0.00
# ARCH(20)                                                      29.77
# (p-value)                                                      0.07
# Ljung–Box(10)                                                357.63
# (p-value)                                                      0.00
# Ljung–Box(20)                                                433.58
# (p-value)                                                      0.00
# Ljung–Box(10)^2                                               51.17
# (p-value)                                                      0.00
# Ljung–Box(20)^2                                               55.06
# (p-value)                                                      0.00
# Augmented Dickey–Fuller                                       -4.07
# (p-value)                                                      0.00
#                          Seoul:Row_Houses(HPI)  \
# Mean                                      0.00
# Stdev                                     0.01
# Skewness                                  2.17
# Kurtosis                                  9.03
# Kolmogorov–Smirnov                        0.50
# (p-value)                                 0.00
# Jarque–Bera                             713.33
# (p-value)                                 0.00
# ARCH(10)                                 77.27
# (p-value)                                 0.00
# ARCH(20)                                 80.16
# (p-value)                                 0.00
# Ljung–Box(10)                           399.31
# (p-value)                                 0.00
# Ljung–Box(20)                           516.72
# (p-value)                                 0.00
# Ljung–Box(10)^2                         118.07
# (p-value)                                 0.00
# Ljung–Box(20)^2                         153.76
# (p-value)                                 0.00
# Augmented Dickey–Fuller                  -2.94
# (p-value)                                 0.04
#
#                          Northern Seoul:Row_Houses(HPI)  \
# Mean                                               0.00
# Stdev                                              0.01
# Skewness                                           2.08
# Kurtosis                                           6.77
# Kolmogorov–Smirnov                                 0.50
# (p-value)                                          0.00
# Jarque–Bera                                      449.61
# (p-value)                                          0.00
# ARCH(10)                                          88.36
# (p-value)                                          0.00
# ARCH(20)                                          88.74
# (p-value)                                          0.00
# Ljung–Box(10)                                    468.75
# (p-value)                                          0.00
# Ljung–Box(20)                                    618.33
# (p-value)                                          0.00
# Ljung–Box(10)^2                                  154.76
# (p-value)                                          0.00
# Ljung–Box(20)^2                                  221.63
# (p-value)                                          0.00
# Augmented Dickey–Fuller                           -2.10
# (p-value)                                          0.24
#
#                          Southern Seoul:Row_Houses(HPI)  \
# Mean                                               0.00
# Stdev                                              0.01
# Skewness                                           2.18
# Kurtosis                                          10.02
# Kolmogorov–Smirnov                                 0.49
# (p-value)                                          0.00
# Jarque–Bera                                      847.31
# (p-value)                                          0.00
# ARCH(10)                                          56.38
# (p-value)                                          0.00
# ARCH(20)                                          59.98
# (p-value)                                          0.00
# Ljung–Box(10)                                    277.55
# (p-value)                                          0.00
# Ljung–Box(20)                                    342.92
# (p-value)                                          0.00
# Ljung–Box(10)^2                                   83.33
# (p-value)                                          0.00
# Ljung–Box(20)^2                                  103.00
# (p-value)                                          0.00
# Augmented Dickey–Fuller                           -1.94
# (p-value)                                          0.31
#
#                          6 Large Cities:Row_Houses(HPI)  \
# Mean                                               0.00
# Stdev                                              0.00
# Skewness                                           0.85
# Kurtosis                                           2.91
# Kolmogorov–Smirnov                                 0.50
# (p-value)                                          0.00
# Jarque–Bera                                       79.81
# (p-value)                                          0.00
# ARCH(10)                                          87.96
# (p-value)                                          0.00
# ARCH(20)                                          97.10
# (p-value)                                          0.00
# Ljung–Box(10)                                    507.24
# (p-value)                                          0.00
# Ljung–Box(20)                                    554.53
# (p-value)                                          0.00
# Ljung–Box(10)^2                                  205.91
# (p-value)                                          0.00
# Ljung–Box(20)^2                                  292.87
# (p-value)                                          0.00
# Augmented Dickey–Fuller                           -3.44
# (p-value)                                          0.01
#
#                          Gyeonggi-do:Row_Houses(HPI)  \
# Mean                                            0.00
# Stdev                                           0.01
# Skewness                                        4.34
# Kurtosis                                       27.26
# Kolmogorov–Smirnov                              0.50
# (p-value)                                       0.00
# Jarque–Bera                                 5,814.00
# (p-value)                                       0.00
# ARCH(10)                                       99.05
# (p-value)                                       0.00
# ARCH(20)                                       94.23
# (p-value)                                       0.00
# Ljung–Box(10)                                 323.47
# (p-value)                                       0.00
# Ljung–Box(20)                                 398.50
# (p-value)                                       0.00
# Ljung–Box(10)^2                                92.63
# (p-value)                                       0.00
# Ljung–Box(20)^2                                95.06
# (p-value)                                       0.00
# Augmented Dickey–Fuller                        -4.12
# (p-value)                                       0.00
#
#                          Non-Metropolitan Area:Row_Houses(HPI)
# Mean                                                      0.00
# Stdev                                                     0.00
# Skewness                                                 -0.37
# Kurtosis                                                  2.58
# Kolmogorov–Smirnov                                        0.50
# (p-value)                                                 0.00
# Jarque–Bera                                              50.16
# (p-value)                                                 0.00
# ARCH(10)                                                 43.72
# (p-value)                                                 0.00
# ARCH(20)                                                 60.92
# (p-value)                                                 0.00
# Ljung–Box(10)                                           448.88
# (p-value)                                                 0.00
# Ljung–Box(20)                                           561.31
# (p-value)                                                 0.00
# Ljung–Box(10)^2                                         107.97
# (p-value)                                                 0.00
# Ljung–Box(20)^2                                         109.86
# (p-value)                                                 0.00
# Augmented Dickey–Fuller                                  -2.71
# (p-value)                                                 0.07
# Absolute Bubble Statistics in Full Period
# <style  type="text/css" >
# </style>
# <table id="T_d67d8d6c_1409_11e9_90eb_bc5ff42be77b" >
# <thead>    <tr>
#         <th class="blank level0" ></th>
#         <th class="col_heading level0 col0" >Average</th>
#         <th class="col_heading level0 col1" >Max</th>
#         <th class="col_heading level0 col2" >Max(%)</th>
#         <th class="col_heading level0 col3" >Min</th>
#         <th class="col_heading level0 col4" >Min(%)</th>
#     </tr></thead>
# <tbody>    <tr>
#         <th id="T_d67d8d6c_1409_11e9_90eb_bc5ff42be77blevel0_row0" class="row_heading level0 row0" >Seoul:Apartments(HPI)</th>
#         <td id="T_d67d8d6c_1409_11e9_90eb_bc5ff42be77brow0_col0" class="data row0 col0" >3290.35</td>
#         <td id="T_d67d8d6c_1409_11e9_90eb_bc5ff42be77brow0_col1" class="data row0 col1" >9315.66</td>
#         <td id="T_d67d8d6c_1409_11e9_90eb_bc5ff42be77brow0_col2" class="data row0 col2" >(183%)</td>
#         <td id="T_d67d8d6c_1409_11e9_90eb_bc5ff42be77brow0_col3" class="data row0 col3" >566.475</td>
#         <td id="T_d67d8d6c_1409_11e9_90eb_bc5ff42be77brow0_col4" class="data row0 col4" >(-83%)</td>
#     </tr>    <tr>
#         <th id="T_d67d8d6c_1409_11e9_90eb_bc5ff42be77blevel0_row1" class="row_heading level0 row1" >Northern Seoul:Apartments(HPI)</th>
#         <td id="T_d67d8d6c_1409_11e9_90eb_bc5ff42be77brow1_col0" class="data row1 col0" >2408.13</td>
#         <td id="T_d67d8d6c_1409_11e9_90eb_bc5ff42be77brow1_col1" class="data row1 col1" >6202.18</td>
#         <td id="T_d67d8d6c_1409_11e9_90eb_bc5ff42be77brow1_col2" class="data row1 col2" >(158%)</td>
#         <td id="T_d67d8d6c_1409_11e9_90eb_bc5ff42be77brow1_col3" class="data row1 col3" >197.541</td>
#         <td id="T_d67d8d6c_1409_11e9_90eb_bc5ff42be77brow1_col4" class="data row1 col4" >(-92%)</td>
#     </tr>    <tr>
#         <th id="T_d67d8d6c_1409_11e9_90eb_bc5ff42be77blevel0_row2" class="row_heading level0 row2" >Southern Seoul:Apartments(HPI)</th>
#         <td id="T_d67d8d6c_1409_11e9_90eb_bc5ff42be77brow2_col0" class="data row2 col0" >4055.16</td>
#         <td id="T_d67d8d6c_1409_11e9_90eb_bc5ff42be77brow2_col1" class="data row2 col1" >12299.4</td>
#         <td id="T_d67d8d6c_1409_11e9_90eb_bc5ff42be77brow2_col2" class="data row2 col2" >(203%)</td>
#         <td id="T_d67d8d6c_1409_11e9_90eb_bc5ff42be77brow2_col3" class="data row2 col3" >429.016</td>
#         <td id="T_d67d8d6c_1409_11e9_90eb_bc5ff42be77brow2_col4" class="data row2 col4" >(-89%)</td>
#     </tr>    <tr>
#         <th id="T_d67d8d6c_1409_11e9_90eb_bc5ff42be77blevel0_row3" class="row_heading level0 row3" >6 Large Cities:Apartments(HPI)</th>
#         <td id="T_d67d8d6c_1409_11e9_90eb_bc5ff42be77brow3_col0" class="data row3 col0" >325.732</td>
#         <td id="T_d67d8d6c_1409_11e9_90eb_bc5ff42be77brow3_col1" class="data row3 col1" >1137.7</td>
#         <td id="T_d67d8d6c_1409_11e9_90eb_bc5ff42be77brow3_col2" class="data row3 col2" >(249%)</td>
#         <td id="T_d67d8d6c_1409_11e9_90eb_bc5ff42be77brow3_col3" class="data row3 col3" >30.1186</td>
#         <td id="T_d67d8d6c_1409_11e9_90eb_bc5ff42be77brow3_col4" class="data row3 col4" >(-91%)</td>
#     </tr>    <tr>
#         <th id="T_d67d8d6c_1409_11e9_90eb_bc5ff42be77blevel0_row4" class="row_heading level0 row4" >Gyeonggi-do:Apartments(HPI)</th>
#         <td id="T_d67d8d6c_1409_11e9_90eb_bc5ff42be77brow4_col0" class="data row4 col0" >1331.85</td>
#         <td id="T_d67d8d6c_1409_11e9_90eb_bc5ff42be77brow4_col1" class="data row4 col1" >3720.88</td>
#         <td id="T_d67d8d6c_1409_11e9_90eb_bc5ff42be77brow4_col2" class="data row4 col2" >(179%)</td>
#         <td id="T_d67d8d6c_1409_11e9_90eb_bc5ff42be77brow4_col3" class="data row4 col3" >70.8455</td>
#         <td id="T_d67d8d6c_1409_11e9_90eb_bc5ff42be77brow4_col4" class="data row4 col4" >(-95%)</td>
#     </tr>    <tr>
#         <th id="T_d67d8d6c_1409_11e9_90eb_bc5ff42be77blevel0_row5" class="row_heading level0 row5" >Gangwon-do:Apartments(HPI)</th>
#         <td id="T_d67d8d6c_1409_11e9_90eb_bc5ff42be77brow5_col0" class="data row5 col0" >194.301</td>
#         <td id="T_d67d8d6c_1409_11e9_90eb_bc5ff42be77brow5_col1" class="data row5 col1" >644.284</td>
#         <td id="T_d67d8d6c_1409_11e9_90eb_bc5ff42be77brow5_col2" class="data row5 col2" >(232%)</td>
#         <td id="T_d67d8d6c_1409_11e9_90eb_bc5ff42be77brow5_col3" class="data row5 col3" >32.3033</td>
#         <td id="T_d67d8d6c_1409_11e9_90eb_bc5ff42be77brow5_col4" class="data row5 col4" >(-83%)</td>
#     </tr>    <tr>
#         <th id="T_d67d8d6c_1409_11e9_90eb_bc5ff42be77blevel0_row6" class="row_heading level0 row6" >Chungcheongbuk-do:Apartments(HPI)</th>
#         <td id="T_d67d8d6c_1409_11e9_90eb_bc5ff42be77brow6_col0" class="data row6 col0" >255.932</td>
#         <td id="T_d67d8d6c_1409_11e9_90eb_bc5ff42be77brow6_col1" class="data row6 col1" >595.639</td>
#         <td id="T_d67d8d6c_1409_11e9_90eb_bc5ff42be77brow6_col2" class="data row6 col2" >(133%)</td>
#         <td id="T_d67d8d6c_1409_11e9_90eb_bc5ff42be77brow6_col3" class="data row6 col3" >19.9111</td>
#         <td id="T_d67d8d6c_1409_11e9_90eb_bc5ff42be77brow6_col4" class="data row6 col4" >(-92%)</td>
#     </tr>    <tr>
#         <th id="T_d67d8d6c_1409_11e9_90eb_bc5ff42be77blevel0_row7" class="row_heading level0 row7" >Chungcheongnam-do:Apartments(HPI)</th>
#         <td id="T_d67d8d6c_1409_11e9_90eb_bc5ff42be77brow7_col0" class="data row7 col0" >185.204</td>
#         <td id="T_d67d8d6c_1409_11e9_90eb_bc5ff42be77brow7_col1" class="data row7 col1" >596.522</td>
#         <td id="T_d67d8d6c_1409_11e9_90eb_bc5ff42be77brow7_col2" class="data row7 col2" >(222%)</td>
#         <td id="T_d67d8d6c_1409_11e9_90eb_bc5ff42be77brow7_col3" class="data row7 col3" >11.0806</td>
#         <td id="T_d67d8d6c_1409_11e9_90eb_bc5ff42be77brow7_col4" class="data row7 col4" >(-94%)</td>
#     </tr>    <tr>
#         <th id="T_d67d8d6c_1409_11e9_90eb_bc5ff42be77blevel0_row8" class="row_heading level0 row8" >Jeollabuk-do:Apartments(HPI)</th>
#         <td id="T_d67d8d6c_1409_11e9_90eb_bc5ff42be77brow8_col0" class="data row8 col0" >231.232</td>
#         <td id="T_d67d8d6c_1409_11e9_90eb_bc5ff42be77brow8_col1" class="data row8 col1" >1057.9</td>
#         <td id="T_d67d8d6c_1409_11e9_90eb_bc5ff42be77brow8_col2" class="data row8 col2" >(358%)</td>
#         <td id="T_d67d8d6c_1409_11e9_90eb_bc5ff42be77brow8_col3" class="data row8 col3" >22.8853</td>
#         <td id="T_d67d8d6c_1409_11e9_90eb_bc5ff42be77brow8_col4" class="data row8 col4" >(-90%)</td>
#     </tr>    <tr>
#         <th id="T_d67d8d6c_1409_11e9_90eb_bc5ff42be77blevel0_row9" class="row_heading level0 row9" >Jeollanam-do:Apartments(HPI)</th>
#         <td id="T_d67d8d6c_1409_11e9_90eb_bc5ff42be77brow9_col0" class="data row9 col0" >139.804</td>
#         <td id="T_d67d8d6c_1409_11e9_90eb_bc5ff42be77brow9_col1" class="data row9 col1" >276.265</td>
#         <td id="T_d67d8d6c_1409_11e9_90eb_bc5ff42be77brow9_col2" class="data row9 col2" >(98%)</td>
#         <td id="T_d67d8d6c_1409_11e9_90eb_bc5ff42be77brow9_col3" class="data row9 col3" >31.4307</td>
#         <td id="T_d67d8d6c_1409_11e9_90eb_bc5ff42be77brow9_col4" class="data row9 col4" >(-78%)</td>
#     </tr>    <tr>
#         <th id="T_d67d8d6c_1409_11e9_90eb_bc5ff42be77blevel0_row10" class="row_heading level0 row10" >Gyeongsangbuk-do:Apartments(HPI)</th>
#         <td id="T_d67d8d6c_1409_11e9_90eb_bc5ff42be77brow10_col0" class="data row10 col0" >236.154</td>
#         <td id="T_d67d8d6c_1409_11e9_90eb_bc5ff42be77brow10_col1" class="data row10 col1" >484.548</td>
#         <td id="T_d67d8d6c_1409_11e9_90eb_bc5ff42be77brow10_col2" class="data row10 col2" >(105%)</td>
#         <td id="T_d67d8d6c_1409_11e9_90eb_bc5ff42be77brow10_col3" class="data row10 col3" >3.48114</td>
#         <td id="T_d67d8d6c_1409_11e9_90eb_bc5ff42be77brow10_col4" class="data row10 col4" >(-99%)</td>
#     </tr>    <tr>
# ...
# Jeollanam-do:Apartments(HPI)                           -156.37
# Gyeongsangbuk-do:Apartments(HPI)                       -270.80
# Gyeongsangnam-do:Apartments(HPI)                       -271.06
# Non-Metropolitan Area:Apartments(HPI)                  -150.89
# Non-Metropolitan Area:Detached_Houses(HPI)             -108.23
# Non-Metropolitan Area:Row_Houses(HPI)                   -90.22
#
#                                             Arbitrage_12M(Long)
# Seoul:Apartments(HPI)                                 -1,177.04
# Seoul:Detached_Houses(HPI)                                 0.00
# Seoul:Row_Houses(HPI)                                   -225.74
# Northern Seoul:Apartments(HPI)                          -697.93
# Northern Seoul:Detached_Houses(HPI)                        0.00
# Northern Seoul:Row_Houses(HPI)                           -24.04
# Southern Seoul:Apartments(HPI)                        -1,226.58
# Southern Seoul:Detached_Houses(HPI)                        0.00
# Southern Seoul:Row_Houses(HPI)                          -473.34
# 6 Large Cities:Apartments(HPI)                             0.00
# 6 Large Cities:Detached_Houses(HPI)                        0.00
# 6 Large Cities:Row_Houses(HPI)                             0.00
# Gyeonggi-do:Apartments(HPI)                             -119.93
# Gyeonggi-do:Detached_Houses(HPI)                         -52.95
# Gyeonggi-do:Row_Houses(HPI)                                0.00
# Gangwon-do:Apartments(HPI)                                 0.00
# Chungcheongbuk-do:Apartments(HPI)                        -19.91
# Chungcheongnam-do:Apartments(HPI)                        -25.61
# Jeollabuk-do:Apartments(HPI)                            -187.86
# Jeollanam-do:Apartments(HPI)                             -62.96
# Gyeongsangbuk-do:Apartments(HPI)                        -324.60
# Gyeongsangnam-do:Apartments(HPI)                           0.00
# Non-Metropolitan Area:Apartments(HPI)                      0.00
# Non-Metropolitan Area:Detached_Houses(HPI)                 0.00
# Non-Metropolitan Area:Row_Houses(HPI)                      0.00
#                                             Arbitrage_12M(Short)  \
# Seoul:Apartments(HPI)                                          0
# Seoul:Detached_Houses(HPI)                                     3
# Seoul:Row_Houses(HPI)                                          0
# Northern Seoul:Apartments(HPI)                                 0
# Northern Seoul:Detached_Houses(HPI)                            1
# Northern Seoul:Row_Houses(HPI)                                 0
# Southern Seoul:Apartments(HPI)                                 0
# Southern Seoul:Detached_Houses(HPI)                            3
# Southern Seoul:Row_Houses(HPI)                                 0
# 6 Large Cities:Apartments(HPI)                                 1
# 6 Large Cities:Detached_Houses(HPI)                            0
# 6 Large Cities:Row_Houses(HPI)                                 0
# Gyeonggi-do:Apartments(HPI)                                    0
# Gyeonggi-do:Detached_Houses(HPI)                               1
# Gyeonggi-do:Row_Houses(HPI)                                    0
# Gangwon-do:Apartments(HPI)                                     2
# Chungcheongbuk-do:Apartments(HPI)                              1
# Chungcheongnam-do:Apartments(HPI)                              2
# Jeollabuk-do:Apartments(HPI)                                   2
# Jeollanam-do:Apartments(HPI)                                   0
# Gyeongsangbuk-do:Apartments(HPI)                               0
# Gyeongsangnam-do:Apartments(HPI)                               2
# Non-Metropolitan Area:Apartments(HPI)                          0
# Non-Metropolitan Area:Detached_Houses(HPI)                     2
# Non-Metropolitan Area:Row_Houses(HPI)                          0
#
#                                             Arbitrage_6M(Short)  \
# Seoul:Apartments(HPI)                                        11
# Seoul:Detached_Houses(HPI)                                   14
# Seoul:Row_Houses(HPI)                                        11
# Northern Seoul:Apartments(HPI)                               11
# Northern Seoul:Detached_Houses(HPI)                          12
# Northern Seoul:Row_Houses(HPI)                               11
# Southern Seoul:Apartments(HPI)                               11
# Southern Seoul:Detached_Houses(HPI)                          15
# Southern Seoul:Row_Houses(HPI)                               11
# 6 Large Cities:Apartments(HPI)                               14
# 6 Large Cities:Detached_Houses(HPI)                          15
# 6 Large Cities:Row_Houses(HPI)                               14
# Gyeonggi-do:Apartments(HPI)                                  10
# Gyeonggi-do:Detached_Houses(HPI)                             12
# Gyeonggi-do:Row_Houses(HPI)                                  11
# Gangwon-do:Apartments(HPI)                                   14
# Chungcheongbuk-do:Apartments(HPI)                            13
# Chungcheongnam-do:Apartments(HPI)                            14
# Jeollabuk-do:Apartments(HPI)                                 13
# Jeollanam-do:Apartments(HPI)                                 13
# Gyeongsangbuk-do:Apartments(HPI)                             14
# Gyeongsangnam-do:Apartments(HPI)                             15
# Non-Metropolitan Area:Apartments(HPI)                        15
# Non-Metropolitan Area:Detached_Houses(HPI)                   14
# Non-Metropolitan Area:Row_Houses(HPI)                        14
#
#                                             Arbitrage_6M(Long)  \
# Seoul:Apartments(HPI)                                       11
# Seoul:Detached_Houses(HPI)                                  10
# Seoul:Row_Houses(HPI)                                       14
# Northern Seoul:Apartments(HPI)                              13
# Northern Seoul:Detached_Houses(HPI)                         11
# Northern Seoul:Row_Houses(HPI)                              13
# Southern Seoul:Apartments(HPI)                              13
# Southern Seoul:Detached_Houses(HPI)                         12
# Southern Seoul:Row_Houses(HPI)                              15
# 6 Large Cities:Apartments(HPI)                              14
# 6 Large Cities:Detached_Houses(HPI)                          8
# 6 Large Cities:Row_Houses(HPI)                              14
# Gyeonggi-do:Apartments(HPI)                                 14
# Gyeonggi-do:Detached_Houses(HPI)                            15
# Gyeonggi-do:Row_Houses(HPI)                                 13
# Gangwon-do:Apartments(HPI)                                  15
# Chungcheongbuk-do:Apartments(HPI)                           14
# Chungcheongnam-do:Apartments(HPI)                           15
# Jeollabuk-do:Apartments(HPI)                                15
# Jeollanam-do:Apartments(HPI)                                14
# Gyeongsangbuk-do:Apartments(HPI)                            13
# Gyeongsangnam-do:Apartments(HPI)                            15
# Non-Metropolitan Area:Apartments(HPI)                       15
# Non-Metropolitan Area:Detached_Houses(HPI)                  13
# Non-Metropolitan Area:Row_Houses(HPI)                       15
#
#                                             Arbitrage_12M(Long)
# Seoul:Apartments(HPI)                                         3
# Seoul:Detached_Houses(HPI)                                    3
# Seoul:Row_Houses(HPI)                                         5
# Northern Seoul:Apartments(HPI)                                3
# Northern Seoul:Detached_Houses(HPI)                           4
# Northern Seoul:Row_Houses(HPI)                                3
# Southern Seoul:Apartments(HPI)                                2
# Southern Seoul:Detached_Houses(HPI)                           5
# Southern Seoul:Row_Houses(HPI)                                6
# 6 Large Cities:Apartments(HPI)                                3
# 6 Large Cities:Detached_Houses(HPI)                           4
# 6 Large Cities:Row_Houses(HPI)                                1
# Gyeonggi-do:Apartments(HPI)                                   5
# Gyeonggi-do:Detached_Houses(HPI)                              5
# Gyeonggi-do:Row_Houses(HPI)                                   3
# Gangwon-do:Apartments(HPI)                                    4
# Chungcheongbuk-do:Apartments(HPI)                             5
# Chungcheongnam-do:Apartments(HPI)                             1
# Jeollabuk-do:Apartments(HPI)                                  1
# Jeollanam-do:Apartments(HPI)                                  3
# Gyeongsangbuk-do:Apartments(HPI)                              9
# Gyeongsangnam-do:Apartments(HPI)                              3
# Non-Metropolitan Area:Apartments(HPI)                         5
# Non-Metropolitan Area:Detached_Houses(HPI)                    0
# Non-Metropolitan Area:Row_Houses(HPI)                         4
#                                             Arbitrage_12M(Short)  \
# Seoul:Apartments(HPI)                                       0.00
# Seoul:Detached_Houses(HPI)                                 27.70
# Seoul:Row_Houses(HPI)                                       0.00
# Northern Seoul:Apartments(HPI)                              0.00
# Northern Seoul:Detached_Houses(HPI)                        63.44
# Northern Seoul:Row_Houses(HPI)                              0.00
# Southern Seoul:Apartments(HPI)                              0.00
# Southern Seoul:Detached_Houses(HPI)                       230.21
# Southern Seoul:Row_Houses(HPI)                              0.00
# 6 Large Cities:Apartments(HPI)                             87.43
# 6 Large Cities:Detached_Houses(HPI)                         0.00
# 6 Large Cities:Row_Houses(HPI)                              0.00
# Gyeonggi-do:Apartments(HPI)                                 0.00
# Gyeonggi-do:Detached_Houses(HPI)                           57.23
# Gyeonggi-do:Row_Houses(HPI)                                 0.00
# Gangwon-do:Apartments(HPI)                                 43.13
# Chungcheongbuk-do:Apartments(HPI)                         117.26
# Chungcheongnam-do:Apartments(HPI)                           9.55
# Jeollabuk-do:Apartments(HPI)                              138.17
# Jeollanam-do:Apartments(HPI)                                0.00
# Gyeongsangbuk-do:Apartments(HPI)                            0.00
# Gyeongsangnam-do:Apartments(HPI)                           33.12
# Non-Metropolitan Area:Apartments(HPI)                       0.00
# Non-Metropolitan Area:Detached_Houses(HPI)                 90.42
# Non-Metropolitan Area:Row_Houses(HPI)                       0.00
#
#                                             Arbitrage_6M(Short)  \
# Seoul:Apartments(HPI)                                  3,635.63
# Seoul:Detached_Houses(HPI)                             1,918.36
# Seoul:Row_Houses(HPI)                                    821.86
# Northern Seoul:Apartments(HPI)                         2,535.31
# Northern Seoul:Detached_Houses(HPI)                    1,995.05
# Northern Seoul:Row_Houses(HPI)                           732.54
# Southern Seoul:Apartments(HPI)                         5,030.72
# Southern Seoul:Detached_Houses(HPI)                    2,222.37
# Southern Seoul:Row_Houses(HPI)                           949.54
# 6 Large Cities:Apartments(HPI)                           448.31
# 6 Large Cities:Detached_Houses(HPI)                      336.06
# 6 Large Cities:Row_Houses(HPI)                           177.08
# Gyeonggi-do:Apartments(HPI)                            1,447.94
# Gyeonggi-do:Detached_Houses(HPI)                         917.66
# Gyeonggi-do:Row_Houses(HPI)                              480.91
# Gangwon-do:Apartments(HPI)                               261.75
# Chungcheongbuk-do:Apartments(HPI)                        305.35
# Chungcheongnam-do:Apartments(HPI)                        197.13
# Jeollabuk-do:Apartments(HPI)                             344.76
# Jeollanam-do:Apartments(HPI)                             167.95
# Gyeongsangbuk-do:Apartments(HPI)                         236.24
# Gyeongsangnam-do:Apartments(HPI)                         452.59
# Non-Metropolitan Area:Apartments(HPI)                    235.68
# Non-Metropolitan Area:Detached_Houses(HPI)               127.74
# Non-Metropolitan Area:Row_Houses(HPI)                     65.99
#
#                                             Arbitrage_6M(Long)  \
# Seoul:Apartments(HPI)                                -2,154.86
# Seoul:Detached_Houses(HPI)                             -543.15
# Seoul:Row_Houses(HPI)                                  -474.15
# Northern Seoul:Apartments(HPI)                       -1,689.40
# Northern Seoul:Detached_Houses(HPI)                    -498.11
# Northern Seoul:Row_Houses(HPI)                         -485.47
# Southern Seoul:Apartments(HPI)                       -2,470.34
# Southern Seoul:Detached_Houses(HPI)                    -472.52
# Southern Seoul:Row_Houses(HPI)                         -507.71
# 6 Large Cities:Apartments(HPI)                         -246.61
# 6 Large Cities:Detached_Houses(HPI)                     -95.33
# 6 Large Cities:Row_Houses(HPI)                         -100.80
# Gyeonggi-do:Apartments(HPI)                          -1,139.50
# Gyeonggi-do:Detached_Houses(HPI)                       -310.80
# Gyeonggi-do:Row_Houses(HPI)                            -289.66
# Gangwon-do:Apartments(HPI)                             -246.33
# Chungcheongbuk-do:Apartments(HPI)                      -203.93
# Chungcheongnam-do:Apartments(HPI)                      -308.48
# Jeollabuk-do:Apartments(HPI)                           -210.36
# Jeollanam-do:Apartments(HPI)                           -189.61
# Gyeongsangbuk-do:Apartments(HPI)                       -130.90
# Gyeongsangnam-do:Apartments(HPI)                       -242.84
# Non-Metropolitan Area:Apartments(HPI)                  -148.40
# Non-Metropolitan Area:Detached_Houses(HPI)             -114.67
# Non-Metropolitan Area:Row_Houses(HPI)                   -80.91
#
#                                             Arbitrage_12M(Long)
# Seoul:Apartments(HPI)                                   -791.98
# Seoul:Detached_Houses(HPI)                              -179.86
# Seoul:Row_Houses(HPI)                                    -81.31
# Northern Seoul:Apartments(HPI)                          -186.60
# Northern Seoul:Detached_Houses(HPI)                     -149.25
# Northern Seoul:Row_Houses(HPI)                          -207.08
# Southern Seoul:Apartments(HPI)                          -250.92
# Southern Seoul:Detached_Houses(HPI)                     -106.31
# Southern Seoul:Row_Houses(HPI)                          -124.13
# 6 Large Cities:Apartments(HPI)                           -94.42
# 6 Large Cities:Detached_Houses(HPI)                      -76.71
# 6 Large Cities:Row_Houses(HPI)                           -26.94
# Gyeonggi-do:Apartments(HPI)                             -236.28
# Gyeonggi-do:Detached_Houses(HPI)                        -116.69
# Gyeonggi-do:Row_Houses(HPI)                             -107.00
# Gangwon-do:Apartments(HPI)                              -133.30
# Chungcheongbuk-do:Apartments(HPI)                       -123.95
# Chungcheongnam-do:Apartments(HPI)                       -277.27
# Jeollabuk-do:Apartments(HPI)                             -85.09
# Jeollanam-do:Apartments(HPI)                            -230.70
# Gyeongsangbuk-do:Apartments(HPI)                        -124.90
# Gyeongsangnam-do:Apartments(HPI)                         -70.87
# Non-Metropolitan Area:Apartments(HPI)                    -86.25
# Non-Metropolitan Area:Detached_Houses(HPI)                 0.00
# Non-Metropolitan Area:Row_Houses(HPI)                    -36.32
